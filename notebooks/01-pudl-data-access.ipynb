# %% [markdown]
# <a href="https://www.kaggle.com/code/catalystcooperative/01-pudl-data-access?scriptVersionId=145889607" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import sys

print(f"Python version: {sys.version}")
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sqlalchemy as sa

print(f"{np.__version__=}")
print(f"{pd.__version__=}")
print(f"{sa.__version__=}")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in sorted(filenames):
        print(os.path.join(dirname, filename))


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
import pathlib
pudl_path = pathlib.Path("/kaggle/input/pudl-project")
# Out:
# Python version: 3.10.12 | packaged by conda-forge | (main, Jun 23 2023, 22:40:32) [GCC 12.3.0]
# np.__version__='1.23.5'
# pd.__version__='2.0.3'
# sa.__version__='2.0.17'
# /kaggle/input/pudl-project/censusdp1tract.sqlite
# /kaggle/input/pudl-project/ferc1.sqlite
# /kaggle/input/pudl-project/ferc1_xbrl.sqlite
# /kaggle/input/pudl-project/ferc1_xbrl_datapackage.json
# /kaggle/input/pudl-project/ferc1_xbrl_taxonomy_metadata.json
# /kaggle/input/pudl-project/ferc2.sqlite
# /kaggle/input/pudl-project/ferc2_xbrl.sqlite
# /kaggle/input/pudl-project/ferc2_xbrl_datapackage.json
# /kaggle/input/pudl-project/ferc2_xbrl_taxonomy_metadata.json
# /kaggle/input/pudl-project/ferc6.sqlite
# /kaggle/input/pudl-project/ferc60.sqlite
# /kaggle/input/pudl-project/ferc60_xbrl.sqlite
# /kaggle/input/pudl-project/ferc60_xbrl_datapackage.json
# /kaggle/input/pudl-project/ferc60_xbrl_taxonomy_metadata.json
# /kaggle/input/pudl-project/ferc6_xbrl.sqlite
# /kaggle/input/pudl-project/ferc6_xbrl_datapackage.json
# /kaggle/input/pudl-project/ferc6_xbrl_taxonomy_metadata.json
# /kaggle/input/pudl-project/ferc714_xbrl.sqlite
# /kaggle/input/pudl-project/ferc714_xbrl_datapackage.json
# /kaggle/input/pudl-project/ferc714_xbrl_taxonomy_metadata.json
# /kaggle/input/pudl-project/hourly_emissions_epacems.parquet
# /kaggle/input/pudl-project/pudl.sqlite

# %% [markdown]
# ### Visualization settings

# %%
import matplotlib

# %%
# %matplotlib inline

# %%
matplotlib.rcParams["figure.figsize"] = (16, 10)
matplotlib.rcParams["figure.dpi"] = 150
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_colwidth", 1000)

# %% [markdown]
# # Accessing the PUDL SQLite Database
# - Most of the PUDL Project data is distributed using SQLite databases.
# - Python, pandas, and many other libraries have built-in support for reading data from SQLite.
# - We can use the SQLAlchemy library to create a connection to the database that Pandas can use.
# - Documentation of the available tables and columns can be found in the [PUDL Data Dictionary](https://catalystcoop-pudl.readthedocs.io/en/latest/data_dictionaries/pudl_db.html)

# %%
pudl_engine = sa.create_engine(f"sqlite:///{pudl_path}/pudl.sqlite")

# %% [markdown]
# ## Read EIA plant data from the PUDL SQLite Database
# * There are lots of different kinds of data in the PUDL DB.
# * Some tables describe attributes of utilities, plants, generators, and balancing authorities.
# * Other tables contain hourly, monthly, or yearly time series of fuel consumed, operating costs, or electricity generated.
# * We'll read the EIA plants table, and use `.convert_dtypes()` to ensure that we don't get any `object` columns since SQLite's data types aren't as rich as those available from Pandas.
# * Power plants are industrial facilities operated by a single utility, but they can have multiple owners, and host multiple generation units.
# * The `plants_eia` table contains only information that pertains to all of the equipment at the plant.
# * Most of these attributes are relatively stable, but they can change slowly over time, so each plant as one record for each `report_year`.

# %%
# %%time
plants_eia = pd.read_sql("denorm_plants_eia", pudl_engine).convert_dtypes()
plants_eia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200177 entries, 0 to 200176
# Data columns (total 54 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   plant_id_eia                                  200177 non-null  Int64
#  1   plant_name_eia                                199398 non-null  string
#  2   city                                          190994 non-null  string
#  3   county                                        190479 non-null  string
#  4   latitude                                      192211 non-null  Float64
#  5   longitude                                     194840 non-null  Float64
#  6   state                                         199317 non-null  string
#  7   street_address                                184478 non-null  string
#  8   zip_code                                      193575 non-null  string
#  9   timezone                                      199398 non-null  string
#  10  report_date                                   200177 non-null  datetime64[ns]
#  11  ash_impoundment                               67277 non-null   boolean
#  12  ash_impoundment_lined                         75898 non-null   boolean
#  13  ash_impoundment_status                        3579 non-null    string
#  14  balancing_authority_code_eia                  185338 non-null  string
#  15  balancing_authority_name_eia                  105169 non-null  string
#  16  datum                                         5561 non-null    string
#  17  energy_storage                                79855 non-null   boolean
#  18  ferc_cogen_docket_no                          8442 non-null    string
#  19  ferc_cogen_status                             178229 non-null  boolean
#  20  ferc_exempt_wholesale_generator_docket_no     19805 non-null   string
#  21  ferc_exempt_wholesale_generator               179151 non-null  boolean
#  22  ferc_small_power_producer_docket_no           37451 non-null   string
#  23  ferc_small_power_producer                     179159 non-null  boolean
#  24  ferc_qualifying_facility_docket_no            3340 non-null    string
#  25  grid_voltage_1_kv                             120209 non-null  Float64
#  26  grid_voltage_2_kv                             2799 non-null    Float64
#  27  grid_voltage_3_kv                             556 non-null     Float64
#  28  iso_rto_code                                  12990 non-null   string
#  29  liquefied_natural_gas_storage                 39887 non-null   boolean
#  30  natural_gas_local_distribution_company        9730 non-null    string
#  31  natural_gas_storage                           47201 non-null   boolean
#  32  natural_gas_pipeline_name_1                   17872 non-null   string
#  33  natural_gas_pipeline_name_2                   1437 non-null    string
#  34  natural_gas_pipeline_name_3                   300 non-null     string
#  35  nerc_region                                   184726 non-null  string
#  36  net_metering                                  1685 non-null    boolean
#  37  pipeline_notes                                1431 non-null    string
#  38  primary_purpose_id_naics                      184695 non-null  Int64
#  39  regulatory_status_code                        155465 non-null  string
#  40  reporting_frequency_code                      63456 non-null   string
#  41  sector_id_eia                                 177386 non-null  Int64
#  42  sector_name_eia                               171240 non-null  string
#  43  service_area                                  19024 non-null   string
#  44  transmission_distribution_owner_id            145282 non-null  Int64
#  45  transmission_distribution_owner_name          145280 non-null  string
#  46  transmission_distribution_owner_state         141123 non-null  string
#  47  utility_id_eia                                199332 non-null  Int64
#  48  water_source                                  98813 non-null   string
#  49  data_maturity                                 200177 non-null  string
#  50  plant_id_pudl                                 200177 non-null  Int64
#  51  utility_name_eia                              199332 non-null  string
#  52  utility_id_pudl                               199332 non-null  Int64
#  53  balancing_authority_code_eia_consistent_rate  184564 non-null  Float64
# dtypes: Float64(6), Int64(7), boolean(9), datetime64[ns](1), string(31)
# memory usage: 74.6 MB
# CPU times: user 6.98 s, sys: 1.03 s, total: 8.01 s
# Wall time: 8.57 s

# %%
plants_eia.sample(10)
# Out:
#         plant_id_eia                   plant_name_eia         city    county  \
# 5999             393                    Control Gorge       Bishop      Inyo
# 187015         62830                 GSPP Imholte CSG    St. Cloud   Stearns
# 192847         64077    Hecate Energy Albany County 1     Coeymans    Albany
# 160701         59228              Leonardo Wind 1 LLC        Alden    Hardin
# 108030         55210         Afton Generating Station      La Mesa  Dona Ana
# 15494           1109                           Keokuk       Keokuk       Lee
# 122626         56181  Genoa Diesel Generating Station        Genoa    Ottawa
# 172348         60549                  ZV Solar 3, LLC  Red Springs   Robeson
# 106732         55133    West Group Generator Building        Eagan      <NA>
# 34945           2783                           Buxton       Buxton      Dare
#
#          latitude  longitude state          street_address zip_code  \
# 5999    37.437921   -118.557    CA          1501 Gorge Rd.    93514
# 187015  45.557945  -94.16324    MN   8158 County Rd 138 St    56301
# 192847  42.515459  -73.83345    NY                     TBD    12143
# 160701  42.498056  -93.36778    IA        140th St & G Ave    50441
# 108030  32.114185  -106.8465    NM   10100 West Afton Road    88044
# 15494     40.3965   -91.3719    IA  523 North Water Street    52632
# 122626    41.5092   -83.3606    OH    Industrial Park Road    43430
# 172348  34.816182  -79.20022    NC      72 Milk Dairy Road    28377
# 106732    44.8196   -93.1156    MN         610 Opperman Dr    55123
# 34945   35.267222  -75.53472    NC         Lightplant Road    27920
#
#                    timezone report_date  ash_impoundment  \
# 5999    America/Los_Angeles  2007-01-01             <NA>
# 187015      America/Chicago  2023-01-01             <NA>
# 192847     America/New_York  2021-01-01             <NA>
# 160701      America/Chicago  2016-01-01            False
# 108030       America/Denver  2022-01-01            False
# 15494       America/Chicago  2018-01-01             <NA>
# 122626     America/New_York  2014-01-01             <NA>
# 172348     America/New_York  2018-01-01            False
# 106732      America/Chicago  2012-01-01             <NA>
# 34945      America/New_York  2003-01-01             <NA>
#
#         ash_impoundment_lined ash_impoundment_status  \
# 5999                     <NA>                   <NA>
# 187015                   <NA>                   <NA>
# 192847                   <NA>                   <NA>
# 160701                  False                   <NA>
# 108030                  False                   <NA>
# 15494                   False                   <NA>
# 122626                  False                   <NA>
# 172348                  False                   <NA>
# 106732                   <NA>                   <NA>
# 34945                    <NA>                   <NA>
#
#        balancing_authority_code_eia  \
# 5999                           LDWP
# 187015                         MISO
# 192847                         NYIS
# 160701                         MISO
# 108030                          PNM
# 15494                          MISO
# 122626                          PJM
# 172348                          DUK
# 106732                         MISO
# 34945                           PJM
#
#                                         balancing_authority_name_eia datum  \
# 5999                                                            <NA>  <NA>
# 187015                                                          <NA>  <NA>
# 192847                          New York Independent System Operator  <NA>
# 160701  Midcontinent Independent Transmission System Operator, Inc..  <NA>
# 108030                          Public Service Company of New Mexico  <NA>
# 15494   Midcontinent Independent Transmission System Operator, Inc..  <NA>
# 122626                                      PJM Interconnection, LLC  <NA>
# 172348                                         Duke Energy Carolinas  <NA>
# 106732                                                          <NA>  <NA>
# 34945                                                           <NA>  <NA>
#
#         energy_storage ferc_cogen_docket_no  ferc_cogen_status  \
# 5999              <NA>                 <NA>              False
# 187015            <NA>                 <NA>               <NA>
# 192847           False                 <NA>              False
# 160701           False                 <NA>              False
# 108030           False                 <NA>              False
# 15494            False                 <NA>              False
# 122626            <NA>                 <NA>              False
# 172348           False                 <NA>              False
# 106732            <NA>                 <NA>              False
# 34945             <NA>                 <NA>              False
#
#        ferc_exempt_wholesale_generator_docket_no  \
# 5999                                        <NA>
# 187015                                      <NA>
# 192847                                      <NA>
# 160701                                      <NA>
# 108030                                      <NA>
# 15494                                       <NA>
# 122626                                      <NA>
# 172348                                      <NA>
# 106732                                      <NA>
# 34945                                       <NA>
#
#         ferc_exempt_wholesale_generator ferc_small_power_producer_docket_no  \
# 5999                              False                                <NA>
# 187015                             <NA>                                <NA>
# 192847                            False                                <NA>
# 160701                            False                        QF13-642-001
# 108030                            False                                <NA>
# 15494                             False                                <NA>
# 122626                            False                                <NA>
# 172348                            False                          15-694-002
# 106732                            False                                <NA>
# 34945                             False                                <NA>
#
#         ferc_small_power_producer ferc_qualifying_facility_docket_no  \
# 5999                        False                               <NA>
# 187015                       <NA>                               <NA>
# 192847                      False                               <NA>
# 160701                       True                               <NA>
# 108030                      False                               <NA>
# 15494                       False                               <NA>
# 122626                      False                               <NA>
# 172348                       True                               <NA>
# 106732                      False                               <NA>
# 34945                       False                               <NA>
#
#         grid_voltage_1_kv  grid_voltage_2_kv  grid_voltage_3_kv iso_rto_code  \
# 5999                 <NA>               <NA>               <NA>         <NA>
# 187015               <NA>               <NA>               <NA>         <NA>
# 192847              115.0               <NA>               <NA>         <NA>
# 160701              12.47               <NA>               <NA>         <NA>
# 108030              345.0               <NA>               <NA>         <NA>
# 15494                69.0               <NA>               <NA>         <NA>
# 122626              12.47               <NA>               <NA>         <NA>
# 172348               23.0               <NA>               <NA>         <NA>
# 106732               13.8               <NA>               <NA>         MISO
# 34945                <NA>               <NA>               <NA>         <NA>
#
#         liquefied_natural_gas_storage natural_gas_local_distribution_company  \
# 5999                             <NA>                                   <NA>
# 187015                           <NA>                                   <NA>
# 192847                           <NA>                                   <NA>
# 160701                           <NA>                                   <NA>
# 108030                          False                                   <NA>
# 15494                            <NA>                                   <NA>
# 122626                           <NA>                                   <NA>
# 172348                          False                                   <NA>
# 106732                           <NA>                                   <NA>
# 34945                            <NA>                                   <NA>
#
#         natural_gas_storage      natural_gas_pipeline_name_1  \
# 5999                   <NA>                             <NA>
# 187015                 <NA>                             <NA>
# 192847                 <NA>                             <NA>
# 160701                 <NA>                             <NA>
# 108030                False  EL PASO NATURAL GAS COMPANY LLC
# 15494                  <NA>                             <NA>
# 122626                 <NA>                             <NA>
# 172348                False                             <NA>
# 106732                 <NA>                             <NA>
# 34945                  <NA>                             <NA>
#
#        natural_gas_pipeline_name_2 natural_gas_pipeline_name_3 nerc_region  \
# 5999                          <NA>                        <NA>        WECC
# 187015                        <NA>                        <NA>        <NA>
# 192847                        <NA>                        <NA>        NPCC
# 160701                        <NA>                        <NA>         MRO
# 108030                        <NA>                        <NA>        WECC
# 15494                         <NA>                        <NA>        SERC
# 122626                        <NA>                        <NA>         RFC
# 172348                        <NA>                        <NA>        SERC
# 106732                        <NA>                        <NA>         MRO
# 34945                         <NA>                        <NA>        SERC
#
#         net_metering pipeline_notes  primary_purpose_id_naics  \
# 5999            <NA>           <NA>                        22
# 187015          <NA>           <NA>                      <NA>
# 192847          <NA>           <NA>                        22
# 160701          <NA>           <NA>                        22
# 108030          <NA>           <NA>                        22
# 15494           <NA>           <NA>                        22
# 122626          <NA>           <NA>                        22
# 172348          <NA>           <NA>                        22
# 106732          <NA>           <NA>                       323
# 34945           <NA>           <NA>                        22
#
#        regulatory_status_code reporting_frequency_code  sector_id_eia  \
# 5999                       RE                     <NA>              1
# 187015                   <NA>                     <NA>           <NA>
# 192847                     NR                     <NA>              2
# 160701                     NR                     <NA>              2
# 108030                     RE                        M              1
# 15494                      RE                        A              1
# 122626                     RE                     <NA>              1
# 172348                     NR                        A              2
# 106732                     NR                     <NA>              6
# 34945                    <NA>                     <NA>              1
#
#                        sector_name_eia service_area  \
# 5999                  Electric Utility         <NA>
# 187015                            <NA>         <NA>
# 192847                     IPP Non-CHP         <NA>
# 160701                            <NA>         <NA>
# 108030                Electric Utility         <NA>
# 15494                 Electric Utility         <NA>
# 122626                Electric Utility         <NA>
# 172348              NAICS-22 Non-Cogen         <NA>
# 106732      Industrial NAICS Non-Cogen         <NA>
# 34945   Electric Utility                       <NA>
#
#         transmission_distribution_owner_id  \
# 5999                                 11208
# 187015                                <NA>
# 192847                               13573
# 160701                                9417
# 108030                                5701
# 15494                                19436
# 122626                                7100
# 172348                                3046
# 106732                               25177
# 34945                                 <NA>
#
#        transmission_distribution_owner_name  \
# 5999                    Los Angeles City of
# 187015                                 <NA>
# 192847           Niagara Mohawk Power Corp.
# 160701        Interstate Power and Light Co
# 108030                  El Paso Electric Co
# 15494              Union Electric Co - (MO)
# 122626              Village of Genoa - (OH)
# 172348          Duke Energy Progress - (NC)
# 106732          Dakota Electric Association
# 34945                                  <NA>
#
#        transmission_distribution_owner_state  utility_id_eia  \
# 5999                                      CA           11208
# 187015                                  <NA>           62719
# 192847                                    NY           63715
# 160701                                    IA           59022
# 108030                                    NM           15473
# 15494                                     MO           19436
# 122626                                    OH            7100
# 172348                                    NC           61119
# 106732                                    MN           18981
# 34945                                   <NA>           13683
#
#                 water_source   data_maturity  plant_id_pudl  \
# 5999    Middle Gorge Tailbay           final           1396
# 187015                  <NA>  monthly_update          12959
# 192847                  <NA>           final          14697
# 160701                  <NA>           final           9091
# 108030                 Wells     provisional             11
# 15494      Mississippi River           final           1041
# 122626                  <NA>           final           4806
# 172348                  <NA>           final           9453
# 106732          Municipality           final           4372
# 34945                   <NA>           final           2159
#
#                                utility_name_eia  utility_id_pudl  \
# 5999    Los Angeles Department of Water & Power             2303
# 187015              Green Street Power Partners             6627
# 192847               Hecate Energy Albany 1 LLC             8136
# 160701                      Leonardo Wind 1 LLC             5140
# 108030                  Public Service Co of NM              274
# 15494                  Union Electric Co - (MO)              334
# 122626                  Village of Genoa - (OH)             3675
# 172348                 SRE Utility Solar 1, LLC             5830
# 106732                             Thomson Corp             3465
# 34945             North Carolina El Member Corp             2639
#
#         balancing_authority_code_eia_consistent_rate
# 5999                                             1.0
# 187015                                           1.0
# 192847                                           1.0
# 160701                                           1.0
# 108030                                           1.0
# 15494                                            1.0
# 122626                                           1.0
# 172348                                           1.0
# 106732                                           1.0
# 34945                                            1.0

# %% [markdown]
# ## Reading FERC plant data from the PUDL SQLite DB
# * The Federal Energy Regulatory Commission (FERC) also reports data about power plants in their [Form 1 - Annual Report of Major Electric Utilities](https://catalystcoop-pudl.readthedocs.io/en/latest/data_sources/ferc1.html).
# * FERC Form 1 focuses primarily on electric utility finances, rather than operations.
# * The Large Steam Plants have particularly detailed capital expenses and O&M costs.

# %%
# %%time
plants_ferc1 = pd.read_sql("denorm_plants_steam_ferc1", pudl_engine)
plants_ferc1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30709 entries, 0 to 30708
# Data columns (total 55 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   report_year                             30709 non-null  int64
#  1   utility_id_ferc1                        30709 non-null  int64
#  2   utility_id_pudl                         30709 non-null  int64
#  3   utility_name_ferc1                      30709 non-null  object
#  4   plant_id_pudl                           30709 non-null  int64
#  5   plant_id_ferc1                          30709 non-null  int64
#  6   plant_name_ferc1                        30709 non-null  object
#  7   asset_retirement_cost                   8844 non-null   float64
#  8   avg_num_employees                       17793 non-null  float64
#  9   capacity_factor                         28571 non-null  float64
#  10  capacity_mw                             30709 non-null  float64
#  11  capex_annual_addition                   23611 non-null  float64
#  12  capex_annual_addition_rolling           19922 non-null  float64
#  13  capex_annual_per_kw                     22972 non-null  float64
#  14  capex_annual_per_mw                     22972 non-null  float64
#  15  capex_annual_per_mw_rolling             19585 non-null  float64
#  16  capex_annual_per_mwh                    21958 non-null  float64
#  17  capex_annual_per_mwh_rolling            18749 non-null  float64
#  18  capex_equipment                         28361 non-null  float64
#  19  capex_land                              21933 non-null  float64
#  20  capex_per_mw                            30429 non-null  float64
#  21  capex_structures                        27504 non-null  float64
#  22  capex_total                             28680 non-null  float64
#  23  capex_wo_retirement_total               30709 non-null  float64
#  24  construction_type                       26330 non-null  object
#  25  construction_year                       29517 non-null  float64
#  26  installation_year                       29268 non-null  float64
#  27  net_generation_mwh                      28574 non-null  float64
#  28  not_water_limited_capacity_mw           22454 non-null  float64
#  29  opex_allowances                         5055 non-null   float64
#  30  opex_boiler                             17268 non-null  float64
#  31  opex_coolants                           1959 non-null   float64
#  32  opex_electric                           23059 non-null  float64
#  33  opex_engineering                        23716 non-null  float64
#  34  opex_fuel                               27388 non-null  float64
#  35  opex_fuel_per_mwh                       26551 non-null  float64
#  36  opex_misc_power                         24057 non-null  float64
#  37  opex_misc_steam                         22707 non-null  float64
#  38  opex_nonfuel_per_mwh                    26468 non-null  float64
#  39  opex_operations                         24801 non-null  float64
#  40  opex_per_mwh                            30373 non-null  float64
#  41  opex_plants                             27363 non-null  float64
#  42  opex_production_total                   28967 non-null  float64
#  43  opex_rents                              9895 non-null   float64
#  44  opex_steam                              18443 non-null  float64
#  45  opex_steam_other                        809 non-null    float64
#  46  opex_structures                         24339 non-null  float64
#  47  opex_total_nonfuel                      28967 non-null  float64
#  48  opex_transfer                           674 non-null    float64
#  49  peak_demand_mw                          25360 non-null  float64
#  50  plant_capability_mw                     7723 non-null   float64
#  51  plant_hours_connected_while_generating  26176 non-null  float64
#  52  plant_type                              29733 non-null  object
#  53  record_id                               30709 non-null  object
#  54  water_limited_capacity_mw               17060 non-null  float64
# dtypes: float64(45), int64(5), object(5)
# memory usage: 12.9+ MB
# CPU times: user 736 ms, sys: 50.7 ms, total: 787 ms
# Wall time: 977 ms

# %%
plants_ferc1.sample(10)
# Out:
#        report_year  utility_id_ferc1  utility_id_pudl  \
# 13241         2002               219              364
# 19616         1996               251              185
# 16418         2001               230              302
# 9901          2000               198               14
# 15409         2021               227              272
# 4159          1998               164              349
# 25199         1994               295              123
# 4524          2013               164              349
# 23298         1999               286               31
# 22491         1995               280              363
#
#                         utility_name_ferc1  plant_id_pudl  plant_id_ferc1  \
# 13241    Wisconsin Power and Light Company            552            4042
# 19616           MidAmerican Energy Company            497            2719
# 16418  Southwestern Public Service Company           1081             602
# 9901             AEP Texas Central Company           7962             103
# 15409   Public Service Company of Colorado            126             518
# 4159   VIRGINIA ELECTRIC AND POWER COMPANY             45            1352
# 25199                Georgia Power Company            653            1030
# 4524   VIRGINIA ELECTRIC AND POWER COMPANY            457            1649
# 23298       Arizona Public Service Company            163              28
# 22491     Wisconsin Electric Power Company            217            2451
#
#          plant_name_ferc1  asset_retirement_cost  avg_num_employees  \
# 13241  s fond du lac u2&3                    NaN                2.0
# 19616           riverside                    NaN               66.0
# 16418          celanese i                    NaN                NaN
# 9901          la palma #7                    NaN                NaN
# 15409            comanche             -3206652.0              128.0
# 4159            bellmeade                    NaN                NaN
# 25199               yates                    NaN              357.0
# 4524            polyester                -4786.0               30.0
# 23298             douglas                    NaN                NaN
# 22491   germantown-unit 3                    NaN                NaN
#
#        capacity_factor  capacity_mw  capex_annual_addition  \
# 13241         0.026650        172.0                    NaN
# 19616         0.410335        141.0                    NaN
# 16418         0.850757         13.3                    0.0
# 9901          0.044088         64.7                    0.0
# 15409         0.451410       1635.3             31689298.0
# 4159          0.136803        297.0                    NaN
# 25199         0.180045       1488.0                    NaN
# 4524          0.230504         58.0             47720534.0
# 23298         0.002574         22.0                    0.0
# 22491         0.000003         53.0                    NaN
#
#        capex_annual_addition_rolling  capex_annual_per_kw  \
# 13241                            NaN                  NaN
# 19616                            NaN                  NaN
# 16418                   0.000000e+00             0.000000
# 9901                    0.000000e+00             0.000000
# 15409                            NaN            19.378278
# 4159                             NaN                  NaN
# 25199                            NaN                  NaN
# 4524                    1.758466e+07           822.767828
# 23298                   6.666667e-01             0.000000
# 22491                            NaN                  NaN
#
#        capex_annual_per_mw  capex_annual_per_mw_rolling  capex_annual_per_mwh  \
# 13241                  NaN                          NaN                   NaN
# 19616                  NaN                          NaN                   NaN
# 16418             0.000000                     0.000000              0.000000
# 9901              0.000000                     0.000000              0.000000
# 15409         19378.277992                          NaN              4.900496
# 4159                   NaN                          NaN                   NaN
# 25199                  NaN                          NaN                   NaN
# 4524         822767.827586                303183.850575            407.469328
# 23298             0.000000                     0.030303              0.000000
# 22491                  NaN                          NaN                   NaN
#
#        capex_annual_per_mwh_rolling  capex_equipment  capex_land  \
# 13241                           NaN     4.970766e+07    324546.0
# 19616                           NaN     4.783084e+07    195852.0
# 16418                      0.000000     1.189589e+06         NaN
# 9901                       0.000000     6.344050e+06    391998.0
# 15409                           NaN     1.425204e+09   6139775.0
# 4159                            NaN     1.888781e+07         NaN
# 25199                           NaN     2.677125e+08   1157244.0
# 4524                     150.149429     4.784396e+07   1015458.0
# 23298                      0.001344     2.185163e+06      9557.0
# 22491                           NaN     8.378407e+06     16648.0
#
#        capex_per_mw  capex_structures   capex_total  \
# 13241      299269.6         1442167.0  5.147437e+07
# 19616      395369.9         7720470.0  5.574716e+07
# 16418       89442.8               NaN  1.189589e+06
# 9901       114421.5          667023.0  7.403071e+06
# 15409      988957.9       189105880.0  1.617243e+09
# 4159        68487.4         1452938.0  2.034075e+07
# 25199      202781.2        32868646.0  3.017384e+08
# 4524       952529.2         6392058.0  5.524669e+07
# 23298       99967.4            4562.0  2.199282e+06
# 22491      169966.4          613168.0  9.008223e+06
#
#        capex_wo_retirement_total construction_type  construction_year  \
# 13241               5.147437e+07      conventional             1994.0
# 19616               5.574716e+07      conventional             1925.0
# 16418               1.189589e+06              None             1965.0
# 9901                7.403071e+06           outdoor             1975.0
# 15409               1.620450e+09           outdoor             1973.0
# 4159                2.034075e+07              None             1991.0
# 25199               3.017384e+08      conventional             1950.0
# 4524                5.525148e+07      conventional             1992.0
# 23298               2.199282e+06              None             1972.0
# 22491               9.008223e+06      conventional             1978.0
#
#        installation_year  net_generation_mwh  not_water_limited_capacity_mw  \
# 13241             1994.0           40153.800                            NaN
# 19616             1961.0          506829.600                            NaN
# 16418             1965.0           99120.000                           13.0
# 9901              1975.0           24988.000                            NaN
# 15409             2010.0         6466549.000                         1171.0
# 4159              1991.0          355922.000                          250.0
# 25199             1974.0         2346866.000                         1229.0
# 4524              1992.0          117114.420                           58.0
# 23298             1972.0             496.074                           16.0
# 22491                NaN               1.374                           62.0
#
#        opex_allowances  opex_boiler  opex_coolants  opex_electric  \
# 13241              NaN          NaN            NaN       192717.0
# 19616          26567.0    1406224.0            NaN       273958.0
# 16418              NaN          NaN            NaN            NaN
# 9901               NaN     152745.0            NaN       135826.0
# 15409              NaN    9897493.0            NaN      2187797.0
# 4159               NaN          NaN            NaN            NaN
# 25199              NaN    9844432.0            NaN      1052135.0
# 4524               NaN     672968.0            NaN        15313.0
# 23298              NaN          NaN            NaN            NaN
# 22491              NaN          NaN            NaN        43877.0
#
#        opex_engineering    opex_fuel  opex_fuel_per_mwh  opex_misc_power  \
# 13241            4750.0    2655734.0          66.139045          52979.0
# 19616          539657.0    7973502.0          15.732116         345115.0
# 16418             140.0     208846.0           2.107002         111321.0
# 9901            23539.0    1173506.0          46.962782          66396.0
# 15409         1217134.0  127988415.0          19.792383        5890849.0
# 4159           143779.0    9989695.0          28.067091         267350.0
# 25199         1919024.0   50342695.0          21.451031        4471838.0
# 4524                NaN    4971584.0          42.450656         768478.0
# 23298             273.0      89379.0         180.172716           3201.0
# 22491            3966.0     119748.0       87152.838428          20605.0
#
#        opex_misc_steam  opex_nonfuel_per_mwh  opex_operations  opex_per_mwh  \
# 13241            117.0              8.714792           1767.0          74.9
# 19616         107497.0              9.184049         256608.0          24.9
# 16418           4573.0              1.839286             20.0           3.9
# 9901           52223.0             33.269609          40903.0          80.2
# 15409        1685699.0              6.483587        1303996.0          26.3
# 4159           33868.0              7.323228         539510.0          35.4
# 25199        1530748.0             11.769003        1697003.0          33.2
# 4524         1153555.0             45.878936              NaN          88.3
# 23298          21731.0            127.446712              NaN         307.6
# 22491           2086.0         -86988.355167           6777.0           0.0
#
#        opex_plants  opex_production_total  opex_rents  opex_steam  \
# 13241      89853.0              3005666.0         NaN         NaN
# 19616     474296.0             12628250.0         NaN   1057068.0
# 16418      58619.0               391156.0         NaN         NaN
# 9901      254341.0              2004847.0         NaN     88849.0
# 15409    2577470.0            169914847.0    908787.0  12983508.0
# 4159      872134.0             12596193.0    495705.0    254427.0
# 25199    3237650.0             77962968.0         NaN   2709606.0
# 4524      165950.0             10344669.0    -10788.0   2228499.0
# 23298       9538.0               152602.0         NaN         NaN
# 22491     112592.0                  226.0         NaN         NaN
#
#        opex_steam_other  opex_structures  opex_total_nonfuel  opex_transfer  \
# 13241               NaN           7749.0            349932.0            NaN
# 19616               NaN         167758.0           4654748.0            NaN
# 16418               NaN           7637.0            182310.0            NaN
# 9901                NaN          16519.0            831341.0            NaN
# 15409               NaN        3273699.0          41926432.0            NaN
# 4159                NaN           -275.0           2606498.0            NaN
# 25199               NaN        1157837.0          27620273.0            NaN
# 4524                NaN         379110.0           5373085.0            NaN
# 23298               NaN          28480.0             63223.0            NaN
# 22491               NaN            458.0           -119522.0            NaN
#
#        peak_demand_mw  plant_capability_mw  \
# 13241           193.0                168.0
# 19616           139.0                135.0
# 16418            16.0                  NaN
# 9901             52.0                  NaN
# 15409          1761.0               1171.0
# 4159              NaN                  NaN
# 25199          1303.0                  NaN
# 4524             63.0                 58.0
# 23298            16.0                  NaN
# 22491            50.0                  NaN
#
#        plant_hours_connected_while_generating          plant_type  \
# 13241                                     NaN  combustion_turbine
# 19616                                  8085.0               steam
# 16418                                  8349.0  combustion_turbine
# 9901                                    510.0  combustion_turbine
# 15409                                  8750.0               steam
# 4159                                   2157.0      combined_cycle
# 25199                                  8692.0               steam
# 4524                                   3183.0               steam
# 23298                                   102.0  combustion_turbine
# 22491                                   384.0  combustion_turbine
#
#                                                                                record_id  \
# 13241                                                           f1_steam_2002_12_194_5_4
# 19616                                                           f1_steam_1996_12_210_0_3
# 16418                                                           f1_steam_2001_12_166_1_1
# 9901                                                             f1_steam_2000_12_24_1_2
# 15409  steam_electric_generating_plant_statistics_large_plants_402_2021_c000822_comanche
# 4159                                                            f1_steam_1998_12_186_3_3
# 25199                                                            f1_steam_1994_12_57_2_3
# 4524                                                            f1_steam_2013_12_186_5_2
# 23298                                                             f1_steam_1999_12_7_2_2
# 22491                                                           f1_steam_1995_12_193_6_3
#
#        water_limited_capacity_mw
# 13241                        NaN
# 19616                        NaN
# 16418                       13.0
# 9901                        52.0
# 15409                     1160.0
# 4159                       230.0
# 25199                        NaN
# 4524                        58.0
# 23298                        NaN
# 22491                       53.0

# %% [markdown]
# ## Reading data tables from the SQLite database
# * In addition to tables that describe the various entities reporting data, we also have the data itself.
# * For instance the EIA-923 reports fuel receipts and costs by power plant:

# %%
# %%time
frc_eia923 = pd.read_sql("denorm_fuel_receipts_costs_eia923", pudl_engine).convert_dtypes()
frc_eia923.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 631975 entries, 0 to 631974
# Data columns (total 36 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   report_date                              631975 non-null  datetime64[ns]
#  1   plant_id_eia                             631975 non-null  Int64
#  2   plant_id_pudl                            631975 non-null  Int64
#  3   plant_name_eia                           631975 non-null  string
#  4   utility_id_eia                           631975 non-null  Int64
#  5   utility_id_pudl                          631975 non-null  Int64
#  6   utility_name_eia                         631975 non-null  string
#  7   state                                    631975 non-null  string
#  8   contract_type_code                       631737 non-null  string
#  9   contract_expiration_date                 269723 non-null  datetime64[ns]
#  10  energy_source_code                       631975 non-null  string
#  11  fuel_type_code_pudl                      631975 non-null  string
#  12  fuel_group_code                          631974 non-null  string
#  13  supplier_name                            631972 non-null  string
#  14  fuel_received_units                      631975 non-null  Int64
#  15  fuel_mmbtu_per_unit                      631975 non-null  Float64
#  16  fuel_cost_per_mmbtu                      585181 non-null  Float64
#  17  bulk_agg_fuel_cost_per_mmbtu             400204 non-null  Float64
#  18  fuel_consumed_mmbtu                      631975 non-null  Float64
#  19  total_fuel_cost                          585181 non-null  Float64
#  20  fuel_cost_from_eiaapi                    631975 non-null  boolean
#  21  sulfur_content_pct                       631975 non-null  Float64
#  22  ash_content_pct                          631975 non-null  Float64
#  23  mercury_content_ppm                      346521 non-null  Float64
#  24  primary_transportation_mode_code         573833 non-null  string
#  25  secondary_transportation_mode_code       32353 non-null   string
#  26  natural_gas_transport_code               363501 non-null  string
#  27  natural_gas_delivery_contract_type_code  187182 non-null  string
#  28  moisture_content_pct                     95329 non-null   Float64
#  29  chlorine_content_ppm                     95329 non-null   Int64
#  30  data_maturity                            631975 non-null  string
#  31  mine_id_msha                             195180 non-null  Int64
#  32  mine_name                                216680 non-null  string
#  33  mine_state                               216680 non-null  string
#  34  coalmine_county_id_fips                  177070 non-null  string
#  35  mine_type_code                           216604 non-null  string
# dtypes: Float64(9), Int64(7), boolean(1), datetime64[ns](2), string(17)
# memory usage: 179.6 MB
# CPU times: user 15.5 s, sys: 1.85 s, total: 17.3 s
# Wall time: 17.7 s

# %%
frc_eia923.sample(10)
# Out:
#        report_date  plant_id_eia  plant_id_pudl         plant_name_eia  \
# 415709  2017-02-01          2965            586                  Tulsa
# 200663  2011-05-01          6250            356                   Mayo
# 223750  2011-10-01          1592           1816       Sithe Medway LLC
# 354010  2015-03-01           983            114           Clifty Creek
# 254260  2012-06-01          2850            288             J M Stuart
# 481440  2018-10-01          6041           2483           H L Spurlock
# 263034  2012-08-01         55818           4655  Frederickson Power LP
# 176787  2010-12-01          6017           1186                 Newton
# 560277  2020-12-01         56328            255              Tontitown
# 203024  2011-06-01           136           1310               Seminole
#
#         utility_id_eia  utility_id_pudl                utility_name_eia state  \
# 415709           15474              275   Public Service Co of Oklahoma    OK
# 200663            3046               97       Carolina Power & Light Co    NC
# 223750            6035             1691        Constellation Power, Inc    MA
# 354010            9269              145  Indiana-Kentucky Electric Corp    IN
# 254260            4922              317         Dayton Power & Light Co    OH
# 481440            5580             1571    East Kentucky Power Coop Inc    KY
# 263034           56613             1810           Frederickson Power LP    WA
# 176787             520              143     Ameren Energy Generating Co    IL
# 560277           17698              301  Southwestern Electric Power Co    AR
# 203024           21554             3118     Seminole Electric Coop, Inc    FL
#
#        contract_type_code contract_expiration_date energy_source_code  \
# 415709                  S                      NaT                 NG
# 200663                  C               2018-12-01                BIT
# 223750                  S                      NaT                DFO
# 354010                  C               2021-12-01                BIT
# 254260                  C               2018-12-01                BIT
# 481440                  C               2018-12-01                BIT
# 263034                  S                      NaT                 NG
# 176787                  C               2011-03-01                DFO
# 560277                  S                      NaT                 NG
# 203024                  C               2014-04-01                BIT
#
#        fuel_type_code_pudl fuel_group_code             supplier_name  \
# 415709                 gas     natural_gas            macquarie cook
# 200663                coal            coal                    consol
# 223750                 oil       petroleum                      gulf
# 354010                coal            coal            resource fuels
# 254260                coal            coal         williamson energy
# 481440                coal            coal      foresight coal sales
# 263034                 gas     natural_gas  bp canada energy company
# 176787                 oil       petroleum                 knapp oil
# 560277                 gas     natural_gas          southwest energy
# 203024                coal            coal           alliance energy
#
#         fuel_received_units  fuel_mmbtu_per_unit  fuel_cost_per_mmbtu  \
# 415709                 1713                 1.04                2.842
# 200663                22735                23.85                4.045
# 223750                   11                 5.85              20.3533
# 354010               119731                22.93                2.507
# 254260               145460                23.27                2.675
# 481440                22492                 24.0                 2.08
# 263034                10584                1.035               4.0849
# 176787                  356                5.754              19.8042
# 560277                  112                 1.03               17.284
# 203024                24121                24.64                3.347
#
#         bulk_agg_fuel_cost_per_mmbtu  fuel_consumed_mmbtu  total_fuel_cost  \
# 415709                          <NA>              1781.52       5063.07984
# 200663                        3.5871            542229.75    2193319.33875
# 223750                       20.3533                64.35      1309.734855
# 354010                          <NA>           2745431.83    6882797.59781
# 254260                          <NA>            3384854.2      9054484.985
# 481440                        1.9485             539808.0       1122800.64
# 263034                        4.0849             10954.44     44747.791956
# 176787                       19.8042             2048.424     40567.398581
# 560277                          <NA>               115.36       1993.88224
# 203024                          <NA>            594341.44    1989260.79968
#
#         fuel_cost_from_eiaapi  sulfur_content_pct  ash_content_pct  \
# 415709                  False                 0.0              0.0
# 200663                  False                0.68             11.5
# 223750                   True                 0.5              0.0
# 354010                  False                2.99              8.2
# 254260                  False                2.64              9.8
# 481440                  False                2.88              7.5
# 263034                   True                 0.0              0.0
# 176787                   True                0.01              0.0
# 560277                  False                 0.0              0.0
# 203024                  False                2.99              9.0
#
#         mercury_content_ppm primary_transportation_mode_code  \
# 415709                  0.0                               PL
# 200663                 <NA>                               RR
# 223750                 <NA>                               TR
# 354010                  0.0                               RV
# 254260                 <NA>                               RV
# 481440                  0.0                               RV
# 263034                  0.0                               PL
# 176787                 <NA>                               TR
# 560277                  0.0                               PL
# 203024                 <NA>                               RR
#
#        secondary_transportation_mode_code natural_gas_transport_code  \
# 415709                               <NA>                       firm
# 200663                               <NA>                       <NA>
# 223750                               <NA>                       <NA>
# 354010                               <NA>                       <NA>
# 254260                               <NA>                       <NA>
# 481440                               <NA>                       <NA>
# 263034                               <NA>                       firm
# 176787                               <NA>                       <NA>
# 560277                               <NA>                       firm
# 203024                               <NA>                       <NA>
#
#        natural_gas_delivery_contract_type_code  moisture_content_pct  \
# 415709                                    firm                  <NA>
# 200663                                    <NA>                  <NA>
# 223750                                    <NA>                  <NA>
# 354010                                    <NA>                 12.21
# 254260                                    <NA>                  <NA>
# 481440                                    <NA>                  10.4
# 263034                                    <NA>                  <NA>
# 176787                                    <NA>                  <NA>
# 560277                                    firm                  <NA>
# 203024                                    <NA>                  <NA>
#
#         chlorine_content_ppm data_maturity  mine_id_msha  \
# 415709                  <NA>         final          <NA>
# 200663                  <NA>         final       4605890
# 223750                  <NA>         final          <NA>
# 354010                     0         final       1519374
# 254260                  <NA>         final       1103141
# 481440                     0         final       1103182
# 263034                  <NA>         final          <NA>
# 176787                  <NA>         final          <NA>
# 560277                  <NA>         final          <NA>
# 203024                  <NA>         final       1502132
#
#                              mine_name mine_state coalmine_county_id_fips  \
# 415709                            <NA>       <NA>                    <NA>
# 200663  miller creek preparation plant         WV                    <NA>
# 223750                            <NA>       <NA>                    <NA>
# 354010                 river view mine         KY                   21225
# 254260                     mach 1 mine         IL                   17199
# 481440                   deer run mine         IL                   17135
# 263034                            <NA>       <NA>                    <NA>
# 176787                            <NA>       <NA>                    <NA>
# 560277                            <NA>       <NA>                    <NA>
# 203024                     dotiki mine         KY                    <NA>
#
#        mine_type_code
# 415709           <NA>
# 200663              P
# 223750           <NA>
# 354010              U
# 254260              U
# 481440              U
# 263034           <NA>
# 176787           <NA>
# 560277           <NA>
# 203024              U

# %% [markdown]
# # Read Hourly Generation & Emissions Data from Apache Parquet
# * The full hourly emissions time series for thousands of US power plants covering 1995-2022 contains almost a billion records.
# * The data is stored in a single [Apache Parquet file](https://parquet.apache.org/) with row-groups defined by year and state.
# * This compressed columnar format enables very efficient queries with appropriate tooling, including [Dask](https://www.dask.org/) and [PyArrow](https://arrow.apache.org/docs/python/index.html).
# * Reading the entire dataset into memory at once will probably exceed the available RAM.
# * The filters use [Disjunctive Normal Form](https://blog.datasyndrome.com/python-and-parquet-performance-e71da65269ce)
# * Using Dask's lazy evaluation and the filter criteria, we can minimize the data read off of disk and limit memory usage.
# * The Dask project has lots of [tutorials and documentation](https://www.dask.org/get-started) if you want to learn more.
# * Other tools like [DuckDB](https://duckdb.org/docs/data/parquet/overview.html) ([Python API](https://duckdb.org/docs/api/python/overview)) also provide good Parquet support.

# %% [markdown]
# ## Using Dask to selectively read Parquet data

# %%
# %%time 
from dask import dataframe as dd
# In a DNF filter, the inner lists of conditions are combined with AND
# while the outer list of conditions are combined with OR
# So this filter will get all 2019 and 2020 records for CO and WY:
state_year_filters = [
    [('year', '=', 2019), ('state', '=', 'CO')],
    [('year', '=', 2019), ('state', '=', 'WY')],
    [('year', '=', 2020), ('state', '=', 'CO')],
    [('year', '=', 2020), ('state', '=', 'WY')],
]
co_wy_cems = dd.read_parquet(
    f"{pudl_path}/hourly_emissions_epacems.parquet",
    engine="pyarrow",
    dtype_backend="pyarrow",
    filters=state_year_filters,
).compute()
co_wy_cems.info()
# Out:
# /opt/conda/lib/python3.10/site-packages/dask/dataframe/io/parquet/core.py:1516: UserWarning: Sorted columns detected: ['year', 'state']
# Use the `index` argument to set a sorted column as your index to create a DataFrame collection with known `divisions`.
#   warnings.warn(
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1662192 entries, 0 to 1662191
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   plant_id_eia               1662192 non-null  int32[pyarrow]
#  1   plant_id_epa               1662192 non-null  int32[pyarrow]
#  2   emissions_unit_id_epa      1662192 non-null  string
#  3   operating_datetime_utc     1662192 non-null  timestamp[ms, tz=UTC][pyarrow]
#  4   year                       1662192 non-null  int32[pyarrow]
#  5   state                      1662192 non-null  dictionary<values=string, indices=int32, ordered=0>[pyarrow]
#  6   operating_time_hours       1662192 non-null  float[pyarrow]
#  7   gross_load_mw              856134 non-null   float[pyarrow]
#  8   heat_content_mmbtu         858087 non-null   float[pyarrow]
#  9   steam_load_1000_lbs        1953 non-null     float[pyarrow]
#  10  so2_mass_lbs               858087 non-null   float[pyarrow]
#  11  so2_mass_measurement_code  858087 non-null   dictionary<values=string, indices=int32, ordered=0>[pyarrow]
#  12  nox_mass_lbs               858087 non-null   float[pyarrow]
#  13  nox_mass_measurement_code  858087 non-null   dictionary<values=string, indices=int32, ordered=0>[pyarrow]
#  14  co2_mass_tons              858087 non-null   float[pyarrow]
#  15  co2_mass_measurement_code  858087 non-null   dictionary<values=string, indices=int32, ordered=0>[pyarrow]
# dtypes: dictionary<values=string, indices=int32, ordered=0>[pyarrow](4), float[pyarrow](7), int32[pyarrow](3), string(1), timestamp[ms, tz=UTC][pyarrow](1)
# memory usage: 114.6 MB
# CPU times: user 1.62 s, sys: 636 ms, total: 2.26 s
# Wall time: 2.22 s

# %%
co_wy_cems.sample(10)
# Out:
#          plant_id_eia  plant_id_epa emissions_unit_id_epa  \
# 733556           8066          8066                  BW73
# 389577          55283         55283                     1
# 1541861          7504          7504                     1
# 1367161         56445         56445                 CT-01
# 1286120         55453         55453                     6
# 1558611          8066          8066                  BW71
# 255932           8219          8219                     3
# 1440046         56998         56998                  CT08
# 827567            469           469                     4
# 357530          55200         55200                   CT6
#
#             operating_datetime_utc  year state  operating_time_hours  \
# 733556   2019-01-23 03:00:00+00:00  2019    WY                   1.0
# 389577   2020-11-10 16:00:00+00:00  2020    CO                   1.0
# 1541861  2020-04-20 12:00:00+00:00  2020    WY                   1.0
# 1367161  2019-05-23 08:00:00+00:00  2019    CO                   0.0
# 1286120  2019-02-20 15:00:00+00:00  2019    CO                   0.0
# 1558611  2020-03-17 10:00:00+00:00  2020    WY                   1.0
# 255932   2020-08-24 03:00:00+00:00  2020    CO                   0.0
# 1440046  2019-09-17 05:00:00+00:00  2019    CO                   0.0
# 827567   2019-10-17 06:00:00+00:00  2019    CO                   1.0
# 357530   2020-03-18 09:00:00+00:00  2020    CO                   1.0
#
#          gross_load_mw  heat_content_mmbtu  steam_load_1000_lbs  so2_mass_lbs  \
# 733556           495.0         4967.200195                 <NA>    834.400024
# 389577           187.0              1489.5                 <NA>         0.894
# 1541861           90.0              1080.0                 <NA>    106.599998
# 1367161           <NA>                <NA>                 <NA>          <NA>
# 1286120           <NA>                <NA>                 <NA>          <NA>
# 1558611          294.0              2846.0                 <NA>    444.299988
# 255932            <NA>                <NA>                 <NA>          <NA>
# 1440046           <NA>                <NA>                 <NA>          <NA>
# 827567           198.0         1984.599976                 <NA>           1.2
# 357530            34.0               282.0                 <NA>         0.169
#
#         so2_mass_measurement_code  nox_mass_lbs nox_mass_measurement_code  \
# 733556                   Measured    372.540009                Calculated
# 389577                   Measured     43.195999                Calculated
# 1541861                  Measured    154.440002                Calculated
# 1367161                      <NA>          <NA>                      <NA>
# 1286120                      <NA>          <NA>                      <NA>
# 1558611                  Measured    395.593994                Calculated
# 255932                       <NA>          <NA>                      <NA>
# 1440046                      <NA>          <NA>                      <NA>
# 827567                   Measured    140.906998                Calculated
# 357530                   Measured         4.512                Calculated
#
#          co2_mass_tons co2_mass_measurement_code
# 733556           521.0                  Measured
# 389577            88.5                  Measured
# 1541861     113.300003                  Measured
# 1367161           <NA>                      <NA>
# 1286120           <NA>                      <NA>
# 1558611          298.5                  Measured
# 255932            <NA>                      <NA>
# 1440046           <NA>                      <NA>
# 827567      117.599998                  Measured
# 357530       16.799999                  Measured

# %% [markdown]
# ## Read all Colorado Emissions Data

# %%
# %%time
colorado_cems = dd.read_parquet(
    f"{pudl_path}/hourly_emissions_epacems.parquet",
    engine="pyarrow",
    dtype_backend="pyarrow",
    filters=[("state", "=", "CO")],
).compute()
colorado_cems.info()
# Out:
# /opt/conda/lib/python3.10/site-packages/dask/dataframe/io/parquet/core.py:1516: UserWarning: Sorted columns detected: ['state']
# Use the `index` argument to set a sorted column as your index to create a DataFrame collection with known `divisions`.
#   warnings.warn(
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13631472 entries, 0 to 13631471
# Data columns (total 16 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   plant_id_eia               int32[pyarrow]
#  1   plant_id_epa               int32[pyarrow]
#  2   emissions_unit_id_epa      string
#  3   operating_datetime_utc     timestamp[ms, tz=UTC][pyarrow]
#  4   year                       int32[pyarrow]
#  5   state                      dictionary<values=string, indices=int32, ordered=0>[pyarrow]
#  6   operating_time_hours       float[pyarrow]
#  7   gross_load_mw              float[pyarrow]
#  8   heat_content_mmbtu         float[pyarrow]
#  9   steam_load_1000_lbs        float[pyarrow]
#  10  so2_mass_lbs               float[pyarrow]
#  11  so2_mass_measurement_code  dictionary<values=string, indices=int32, ordered=0>[pyarrow]
#  12  nox_mass_lbs               float[pyarrow]
#  13  nox_mass_measurement_code  dictionary<values=string, indices=int32, ordered=0>[pyarrow]
#  14  co2_mass_tons              float[pyarrow]
#  15  co2_mass_measurement_code  dictionary<values=string, indices=int32, ordered=0>[pyarrow]
# dtypes: dictionary<values=string, indices=int32, ordered=0>[pyarrow](4), float[pyarrow](7), int32[pyarrow](3), string(1), timestamp[ms, tz=UTC][pyarrow](1)
# memory usage: 934.8 MB
# CPU times: user 2.31 s, sys: 1.34 s, total: 3.65 s
# Wall time: 1.83 s

# %%
colorado_cems.sample(10)
# Out:
#           plant_id_eia  plant_id_epa emissions_unit_id_epa  \
# 2074981            478           478                     1
# 12487512           525           525                    H2
# 1872683          55283         55283                     2
# 393861           55453         55453                     2
# 11934318           492           492                     5
# 2715761            478           478                     3
# 1546069            508           508                     8
# 8100824           6761          6761                   101
# 12355359           465           465                     4
# 5785541          56998         56998                  CT07
#
#              operating_datetime_utc  year state  operating_time_hours  \
# 2074981   2015-01-06 20:00:00+00:00  2015    CO                   1.0
# 12487512  2012-01-27 07:00:00+00:00  2012    CO                   1.0
# 1872683   2010-12-06 18:00:00+00:00  2010    CO                   0.0
# 393861    2022-06-20 04:00:00+00:00  2022    CO                   0.0
# 11934318  2007-12-21 13:00:00+00:00  2007    CO                   1.0
# 2715761   2020-02-25 00:00:00+00:00  2020    CO                   0.0
# 1546069   2010-08-24 20:00:00+00:00  2010    CO                   0.0
# 8100824   2021-01-25 15:00:00+00:00  2021    CO                   1.0
# 12355359  2012-07-10 22:00:00+00:00  2012    CO                   1.0
# 5785541   2018-09-26 12:00:00+00:00  2018    CO                   1.0
#
#           gross_load_mw  heat_content_mmbtu  steam_load_1000_lbs  \
# 2074981            <NA>          113.099998                150.0
# 12487512          207.0         2009.599976                 <NA>
# 1872683            <NA>                <NA>                 <NA>
# 393861             <NA>                <NA>                 <NA>
# 11934318           45.0               450.5                 <NA>
# 2715761            <NA>                <NA>                 <NA>
# 1546069            <NA>                <NA>                 <NA>
# 8100824           300.0         2605.699951                 <NA>
# 12355359          112.0         1356.199951                 <NA>
# 5785541            38.0          384.899994                 <NA>
#
#           so2_mass_lbs so2_mass_measurement_code  nox_mass_lbs  \
# 2074981          0.068                  Measured     22.846001
# 12487512    196.699997                Substitute    635.033997
# 1872683           <NA>                      <NA>          <NA>
# 393861            <NA>                      <NA>          <NA>
# 11934318    288.700012                  Measured    160.828003
# 2715761           <NA>                      <NA>          <NA>
# 1546069           <NA>                      <NA>          <NA>
# 8100824     203.699997                  Measured    315.290009
# 12355359    527.299988                  Measured    377.023987
# 5785541          0.231                  Measured         1.155
#
#          nox_mass_measurement_code  co2_mass_tons co2_mass_measurement_code
# 2074981                 Calculated            6.7                  Measured
# 12487512                Calculated     206.199997   Measured and Substitute
# 1872683                       <NA>           <NA>                      <NA>
# 393861                        <NA>           <NA>                      <NA>
# 11934318                Calculated      46.200001                  Measured
# 2715761                       <NA>           <NA>                      <NA>
# 1546069                       <NA>           <NA>                      <NA>
# 8100824                 Calculated     273.299988                  Measured
# 12355359                Calculated     142.199997                  Measured
# 5785541                 Calculated           22.9                  Measured

# %% [markdown]
# ## Visualize Hourly Power Plant Operations
# * Let's find a particular power plant and look at its long-term operations.
# * Say we want to investigate [Xcel Energy's troubled Comanche coal plant](https://coloradosun.com/?s=comanche%20pueblo) in Pueblo, CO?
# * The EPA CEMS data only has contains the EIA Plant ID, not its name or any ownership information.
# * The PUDL database links these IDs to much more extensive EIA data.
# * We can look for the Comanche plant in the PUDL DB and use that information to select the appropriate EPA CEMS data to plot.

# %%
# %%time
plants_eia = pd.read_sql("denorm_plants_eia", pudl_engine).convert_dtypes()
plants_eia.sample(10)
# Out:
# CPU times: user 7.01 s, sys: 366 ms, total: 7.37 s
# Wall time: 7.76 s
#         plant_id_eia                          plant_name_eia           city  \
# 139946         57352                      Trenton Solar Farm        Trenton
# 124531         56292     Richmond County Generating Facility         Hamlet
# 163852         59573                  Tisbury Landfill Solar        Tisbury
# 178138         61362  NRG Elbow Creek Energy Storage Project     Big Spring
# 81090          50148                        Linde Wilmington     Wilmington
# 115846         55691               Wellton-Mohawk Generating        Wellton
# 196498         65092                            115 G Fisher  Middleborough
# 183291         62158  Sacket Lake Rd #1 Community Solar Farm       Thompson
# 80997          50140                   Resurrection Hospital           <NA>
# 183991         62282                         Pee Dee Solar I        Dillion
#
#              county   latitude  longitude state            street_address  \
# 139946       Mercer    40.2314   -74.7539    NJ  500-520 Brunswick Avenue
# 124531     Richmond  34.842311  -79.73609    NC       162 Cooperative Way
# 163852        Dukes  41.444722  -70.61306    MA         59 Highpoint Lane
# 178138       Howard  32.167575  -101.4792    TX            1003 FM 818 W.
# 81090   Los Angeles   33.78856  -118.2294    CA     Pacific Coast Highway
# 115846         Yuma       <NA>       <NA>    AZ      10800 South Ave 22 E
# 196498     Plymouth  41.877476  -70.83984    MA               0 Gd Circle
# 183291     Sullivan   41.38251  -74.43526    NY       585 S. Maplewood Rd
# 80997          Cook       <NA>       <NA>    IL                      <NA>
# 183991       Dillon  34.399694 -79.361369    SC        Off of Lockemy Hwy
#
#        zip_code             timezone report_date  ash_impoundment  \
# 139946    08638     America/New_York  2019-01-01            False
# 124531    28345     America/New_York  2010-01-01             <NA>
# 163852    02568     America/New_York  2015-01-01            False
# 178138    79720      America/Chicago  2016-01-01            False
# 81090     90744  America/Los_Angeles  2020-01-01            False
# 115846    85356      America/Phoenix  2004-01-01             <NA>
# 196498    02346     America/New_York  2022-01-01             <NA>
# 183291    12701     America/New_York  2020-01-01             <NA>
# 80997     60631      America/Chicago  2010-01-01             <NA>
# 183991    29536     America/New_York  2018-01-01            False
#
#         ash_impoundment_lined ash_impoundment_status  \
# 139946                  False                   <NA>
# 124531                   <NA>                   <NA>
# 163852                  False                   <NA>
# 178138                   <NA>                   <NA>
# 81090                   False                   <NA>
# 115846                   <NA>                   <NA>
# 196498                   <NA>                   <NA>
# 183291                   <NA>                   <NA>
# 80997                    <NA>                   <NA>
# 183991                   <NA>                   <NA>
#
#        balancing_authority_code_eia  \
# 139946                          PJM
# 124531                         CPLE
# 163852                         ISNE
# 178138                         ERCO
# 81090                          LDWP
# 115846                         <NA>
# 196498                         ISNE
# 183291                         NYIS
# 80997                          <NA>
# 183991                         CPLE
#
#                        balancing_authority_name_eia datum  energy_storage  \
# 139946                     PJM Interconnection, LLC  <NA>           False
# 124531                                         <NA>  <NA>            <NA>
# 163852                         ISO New England Inc.  <NA>            <NA>
# 178138  Electric Reliability Council of Texas, Inc.  <NA>            True
# 81090     Los Angeles Department of Water and Power  <NA>           False
# 115846                                         <NA>  <NA>            <NA>
# 196498                         ISO New England Inc.  <NA>           False
# 183291         New York Independent System Operator  <NA>           False
# 80997                                          <NA>  <NA>            <NA>
# 183991                    Duke Energy Progress East  <NA>           False
#
#        ferc_cogen_docket_no  ferc_cogen_status  \
# 139946                 <NA>              False
# 124531                 <NA>              False
# 163852                 <NA>              False
# 178138                 <NA>              False
# 81090           86-1079-000               True
# 115846                 <NA>               <NA>
# 196498                 <NA>              False
# 183291                 <NA>              False
# 80997                  <NA>              False
# 183991                 <NA>              False
#
#        ferc_exempt_wholesale_generator_docket_no  \
# 139946                                      <NA>
# 124531                                      <NA>
# 163852                                      <NA>
# 178138                                      <NA>
# 81090                                       <NA>
# 115846                                      <NA>
# 196498                                      <NA>
# 183291                                      <NA>
# 80997                                       <NA>
# 183991                                      <NA>
#
#         ferc_exempt_wholesale_generator ferc_small_power_producer_docket_no  \
# 139946                            False                                <NA>
# 124531                            False                                <NA>
# 163852                            False                           15-30-000
# 178138                            False                                <NA>
# 81090                             False                                <NA>
# 115846                             <NA>                                <NA>
# 196498                            False                                <NA>
# 183291                            False                         18-1340-000
# 80997                             False                                <NA>
# 183991                            False                        QF16-105-000
#
#         ferc_small_power_producer ferc_qualifying_facility_docket_no  \
# 139946                      False                               <NA>
# 124531                      False                               <NA>
# 163852                       True                               <NA>
# 178138                      False                               <NA>
# 81090                       False                               <NA>
# 115846                       <NA>                               <NA>
# 196498                      False                               <NA>
# 183291                       True                               <NA>
# 80997                       False                               <NA>
# 183991                       True                               <NA>
#
#         grid_voltage_1_kv  grid_voltage_2_kv  grid_voltage_3_kv iso_rto_code  \
# 139946              230.0               <NA>               <NA>         <NA>
# 124531               <NA>               <NA>               <NA>         <NA>
# 163852               23.0               <NA>               <NA>         <NA>
# 178138              12.47               <NA>               <NA>         <NA>
# 81090                34.5               <NA>               <NA>         <NA>
# 115846               <NA>               <NA>               <NA>         <NA>
# 196498               15.0               <NA>               <NA>         <NA>
# 183291                4.8               <NA>               <NA>         <NA>
# 80997                <NA>               <NA>               <NA>         <NA>
# 183991              22.86               <NA>               <NA>         <NA>
#
#         liquefied_natural_gas_storage natural_gas_local_distribution_company  \
# 139946                          False                                   <NA>
# 124531                           <NA>                                   <NA>
# 163852                           <NA>                                   <NA>
# 178138                           <NA>                                   <NA>
# 81090                           False        SOUTHERN CALIFORNIA GAS COMPANY
# 115846                           <NA>                                   <NA>
# 196498                           <NA>                                   <NA>
# 183291                           <NA>                                   <NA>
# 80997                            <NA>                                   <NA>
# 183991                          False                                   <NA>
#
#         natural_gas_storage natural_gas_pipeline_name_1  \
# 139946                False                        <NA>
# 124531                 <NA>                        <NA>
# 163852                 <NA>                        <NA>
# 178138                 <NA>                        <NA>
# 81090                 False                        <NA>
# 115846                 <NA>                        <NA>
# 196498                 <NA>                        <NA>
# 183291                 <NA>                        <NA>
# 80997                  <NA>                        <NA>
# 183991                False                        <NA>
#
#        natural_gas_pipeline_name_2 natural_gas_pipeline_name_3 nerc_region  \
# 139946                        <NA>                        <NA>         RFC
# 124531                        <NA>                        <NA>        SERC
# 163852                        <NA>                        <NA>        NPCC
# 178138                        <NA>                        <NA>         TRE
# 81090                         <NA>                        <NA>        WECC
# 115846                        <NA>                        <NA>        WECC
# 196498                        <NA>                        <NA>        NPCC
# 183291                        <NA>                        <NA>        NPCC
# 80997                         <NA>                        <NA>         UNK
# 183991                        <NA>                        <NA>        SERC
#
#         net_metering pipeline_notes  primary_purpose_id_naics  \
# 139946          <NA>           <NA>                        22
# 124531          <NA>           <NA>                        22
# 163852          <NA>           <NA>                        22
# 178138          <NA>           <NA>                        22
# 81090           <NA>           <NA>                       325
# 115846          <NA>           <NA>                        22
# 196498          <NA>           <NA>                        22
# 183291          <NA>           <NA>                        22
# 80997           <NA>           <NA>                       622
# 183991          <NA>           <NA>                        22
#
#        regulatory_status_code reporting_frequency_code  sector_id_eia  \
# 139946                     RE                        A              1
# 124531                     RE                        M              1
# 163852                     NR                     <NA>              2
# 178138                     NR                     <NA>              2
# 81090                      NR                        A              7
# 115846                   <NA>                     <NA>           <NA>
# 196498                     NR                        A              2
# 183291                     NR                        A              2
# 80997                      NR                     <NA>              5
# 183991                     NR                     <NA>              2
#
#                sector_name_eia                       service_area  \
# 139946        Electric Utility                               <NA>
# 124531        Electric Utility                               <NA>
# 163852      NAICS-22 Non-Cogen                               <NA>
# 178138             IPP Non-CHP                               <NA>
# 81090   Industrial NAICS Cogen                               <NA>
# 115846                    <NA>  Western Area Power Administration
# 196498      NAICS-22 Non-Cogen                               <NA>
# 183291      NAICS-22 Non-Cogen                               <NA>
# 80997               Commercial                               <NA>
# 183991             IPP Non-CHP                               <NA>
#
#         transmission_distribution_owner_id  \
# 139946                               15477
# 124531                                3046
# 163852                               54913
# 178138                               17008
# 81090                                11208
# 115846                                <NA>
# 196498                               12473
# 183291                               13511
# 80997                                 <NA>
# 183991                                3046
#
#            transmission_distribution_owner_name  \
# 139946             Public Service Elec & Gas Co
# 124531            Progress Energy Carolinas Inc
# 163852                   NSTAR Electric Company
# 178138                   Sharyland Utilities LP
# 81090   Los Angeles Department of Water & Power
# 115846                                     <NA>
# 196498             Town of Middleborough - (MA)
# 183291           New York State Elec & Gas Corp
# 80997                                      <NA>
# 183991              Duke Energy Progress - (NC)
#
#        transmission_distribution_owner_state  utility_id_eia  \
# 139946                                    NJ           15477
# 124531                                    NC           13683
# 163852                                    MA           58894
# 178138                                    TX           54888
# 81090                                     CA           15320
# 115846                                  <NA>            5273
# 196498                                    MA           60025
# 183291                                    NY           61194
# 80997                                   <NA>           17259
# 183991                                    SC           61793
#
#                           water_source data_maturity  plant_id_pudl  \
# 139946                            <NA>         final           5633
# 124531                    County Water         final           4879
# 163852                            <NA>         final           7272
# 178138                            <NA>         final          10940
# 81090                     Municipality         final           3474
# 115846  Wellton-Mohawk Irr &Drain Dist         final          13239
# 196498                            <NA>   provisional          16475
# 183291                            <NA>         final          12321
# 80997                             <NA>         final          13487
# 183991                            <NA>         final          12443
#
#                                 utility_name_eia  utility_id_pudl  \
# 139946              Public Service Elec & Gas Co              276
# 124531             North Carolina El Member Corp             2639
# 163852                     CF CVEC Owner One LLC              848
# 178138                       NRG Texas Power LLC             2701
# 81090                                Praxair Inc             2904
# 115846            Dome Valley Energy Partners, L             7066
# 196498  Greenbacker Renewable Energy Corporation             1932
# 183291                          Generate Capital             6027
# 80997                Resurrection Medical Center             9057
# 183991                           Pee Dee Solar I             8892
#
#         balancing_authority_code_eia_consistent_rate
# 139946                                           1.0
# 124531                                           1.0
# 163852                                           1.0
# 178138                                           1.0
# 81090                                            1.0
# 115846                                          <NA>
# 196498                                           1.0
# 183291                                           1.0
# 80997                                           <NA>
# 183991                                           1.0

# %% [markdown]
# By selecting a few informative columns and records with "Comanche" in the plant name, we find that the coal plant we're looking for has `plant_id_eia==470`

# %%
plants_eia.loc[
    plants_eia.plant_name_eia.str.contains("comanche", case=False),
    [
        "plant_id_eia",
        "plant_name_eia",
        "utility_name_eia",
        "city",
        "state",
        "latitude",
        "longitude",
    ]
].drop_duplicates()
# Out:
#         plant_id_eia  plant_name_eia                 utility_name_eia  \
# 7460             470        Comanche    Public Service Co of Colorado
# 50775           6145   Comanche Peak  Luminant Generation Company LLC
# 50788           6145   Comanche Peak             TXU Generation Co LP
# 67387           8059        Comanche    Public Service Co of Oklahoma
# 164570         59656  Comanche Solar                   Novatus Energy
# 164575         59656  Comanche Solar                     Comanche LLC
#
#              city state   latitude  longitude
# 7460       Pueblo    CO    38.2081  -104.5747
# 50775   Glen Rose    TX  32.298365  -97.78552
# 50788   Glen Rose    TX  32.298365  -97.78552
# 67387      Lawton    OK    34.5431   -98.3244
# 164570     Pueblo    CO  38.205278  -104.5667
# 164575     Pueblo    CO  38.205278  -104.5667

# %%
comanche_cems = colorado_cems[colorado_cems.plant_id_eia==470]
comanche_cems.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 569760 entries, 26280 to 13044551
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   plant_id_eia               569760 non-null  int32[pyarrow]
#  1   plant_id_epa               569760 non-null  int32[pyarrow]
#  2   emissions_unit_id_epa      569760 non-null  string
#  3   operating_datetime_utc     569760 non-null  timestamp[ms, tz=UTC][pyarrow]
#  4   year                       569760 non-null  int32[pyarrow]
#  5   state                      569760 non-null  dictionary<values=string, indices=int32, ordered=0>[pyarrow]
#  6   operating_time_hours       569476 non-null  float[pyarrow]
#  7   gross_load_mw              483648 non-null  float[pyarrow]
#  8   heat_content_mmbtu         483648 non-null  float[pyarrow]
#  9   steam_load_1000_lbs        0 non-null       float[pyarrow]
#  10  so2_mass_lbs               483648 non-null  float[pyarrow]
#  11  so2_mass_measurement_code  483648 non-null  dictionary<values=string, indices=int32, ordered=0>[pyarrow]
#  12  nox_mass_lbs               483514 non-null  float[pyarrow]
#  13  nox_mass_measurement_code  479666 non-null  dictionary<values=string, indices=int32, ordered=0>[pyarrow]
#  14  co2_mass_tons              483648 non-null  float[pyarrow]
#  15  co2_mass_measurement_code  483648 non-null  dictionary<values=string, indices=int32, ordered=0>[pyarrow]
# dtypes: dictionary<values=string, indices=int32, ordered=0>[pyarrow](4), float[pyarrow](7), int32[pyarrow](3), string(1), timestamp[ms, tz=UTC][pyarrow](1)
# memory usage: 42.9 MB
