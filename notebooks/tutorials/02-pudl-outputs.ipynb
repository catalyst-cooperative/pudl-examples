# %% [markdown]
# ## Install PUDL
# * Until we get our custom Docker image built, PUDL needs to be installed in your user environment each session.
# * If you are using this notebook on the Catalyst JupyterHub, and this is the first notebook you've used this session, then uncomment the commands in the following cell and run it before anything else.

# %%
#!conda install --yes --quiet python-snappy
#!pip install --upgrade pip
#!pip install --quiet git+https://github.com/catalyst-cooperative/pudl.git@dev
#!cp ~/shared/shared-pudl.yml ~/.pudl.yml

# %%
# import the necessary packages
# %load_ext autoreload
# %autoreload 2

import logging
import sys

import pandas as pd
import sqlalchemy as sa
import random
import pudl

# %%
# setup for python logging
logger=logging.getLogger()
logger.setLevel(logging.INFO)
handler = logging.StreamHandler(stream=sys.stdout)
formatter = logging.Formatter('%(message)s')
handler.setFormatter(formatter)
logger.handlers = [handler]

# %% [markdown]
# ## Set your EIA API Key
# Some of the routines in this notebook pull data from the EIA API to fill in missing fuel cost values. For them to work, you'll need to provide an API KEY. You can [obtain one from EIA here](https://www.eia.gov/opendata/register.php), uncomment the code in the next cell, and use it to set the `API_KEY_EIA` environment variable to be your key. (If you're running this notebook on your own computer and want to set the environment variable outside of the notebook [see this blog post](https://www.twilio.com/blog/2017/01/how-to-set-environment-variables.html))

# %%
# Set EIA API key. If you want to set the API key in this notebook, add your key below and remove comment (#)
# %env API_KEY_EIA=put_your_key_here

# %% [markdown]
# # Using the PUDL output layer
# The PUDL database tables are a clean, [normalized](https://en.wikipedia.org/wiki/Database_normalization) version of US electricity data. Normalized tables are great for databases and storage, but for interactive use, we often want a version of the data that includes plant and utility names and other associated info all in a single dataframe. These are "denormalized" tables. In addition to the referenced names and attributes like latitude and longitude or state, the denormalized tables often contain frequently calculated derived values (like calcuating `total_fuel_cost` from `total_heat_content_mmbtu` and `fuel_cost_per_mmbtu`). The Catalyst team developed a useful tool to access denormalized tables that we call the PUDL output object.

# %% [markdown]
# ## What does the output layer provide?
#
# Right now the output layer provides access to three different kinds of things:
#  * denormalized tables
#  * analytical outputs
#  * partially integrated PUDL datasets that aren't in the database yet

# %% [markdown]
# ## Why is the output layer useful?
# Some benefits of using the output layer:
#  * **Standardized denormalization:** You don't have to manually join the same tables together to get access to common attributes.
#  * **Table caching:** many analyses rely on using the same table multiple times. The PUDL output object caches the tables in memory as pandas dataframes so you don't have to read tables from the database over and over again.
#  * **Time series aggregation:** Some tables are annual, some monthly, some hourly. When you create a PUDL output object you can tell it to aggregate the data to either monthly or annual resolution for analysis.
#  * **Standardized the filling-in of missing data:** There's a ton of missing or incomplete data. If requested, the output objects will use rolling averages and  data from the EIA API try to fill some of that missing data in.

# %% [markdown]
# # Instantiating Output Objects
# * Grab the `pudl_settings`
# * Create a connection to the PUDL Database
# * Instantiate a `PudlTabl` object with that connection

# %%
pudl_settings = pudl.workspace.setup.get_defaults()
pudl_settings
# Out:
# {'pudl_in': '/home/zane/code/catalyst/pudl-work',
#  'data_dir': '/home/zane/code/catalyst/pudl-work/data',
#  'settings_dir': '/home/zane/code/catalyst/pudl-work/settings',
#  'pudl_out': '/home/zane/code/catalyst/pudl-work',
#  'sqlite_dir': '/home/zane/code/catalyst/pudl-work/sqlite',
#  'parquet_dir': '/home/zane/code/catalyst/pudl-work/parquet',
#  'datapkg_dir': '/home/zane/code/catalyst/pudl-work/datapkg',
#  'notebook_dir': '/home/zane/code/catalyst/pudl-work/notebook',
#  'ferc1_db': 'sqlite:////home/zane/code/catalyst/pudl-work/sqlite/ferc1.sqlite',
#  'pudl_db': 'sqlite:////home/zane/code/catalyst/pudl-work/sqlite/pudl.sqlite'}

# %%
pudl_engine = sa.create_engine(pudl_settings["pudl_db"])
pudl_engine
# Out:
# Engine(sqlite:////home/zane/code/catalyst/pudl-work/sqlite/pudl.sqlite)

# %%
# this configuration will return tables without aggregating by a time frequency... we'll explore that more below.
pudl_out = pudl.output.pudltabl.PudlTabl(pudl_engine=pudl_engine)

# %% [markdown]
# ## List the output object methods
# * There are dozens of different data access methods within the `PudlTabl` object. If you want to see all of them with their docstrings, you can un-comment and run `help(pudl_out)` in the next cell.
# * If you type `pudl_out.` and press `Shift` and `Tab` at the same time, you'll see a list of available methods as well.

# %%
#help(pudl_out)

# %% [markdown]
# This cell will print out a simple list of all the available public methods inside the `pudl_out` object

# %%
# this is the master list of all of the methods in the pudl_out object
# they all return a table cooresponding to their name
methods_pudl_out = [
    method_name for method_name in dir(pudl_out)
    if callable(getattr(pudl_out, method_name))    # if it is a method
    and '__' not in method_name                    # remove the internal methods
]
methods_pudl_out
# Out:
# ['adjacency_ba_ferc714',
#  'advanced_metering_infrastructure_eia861',
#  'balancing_authority_assn_eia861',
#  'balancing_authority_eia861',
#  'bf_eia923',
#  'bga',
#  'bga_eia860',
#  'capacity_factor',
#  'demand_forecast_pa_ferc714',
#  'demand_hourly_pa_ferc714',
#  'demand_monthly_ba_ferc714',
#  'demand_response_eia861',
#  'demand_side_management_eia861',
#  'description_pa_ferc714',
#  'distributed_generation_eia861',
#  'distribution_systems_eia861',
#  'dynamic_pricing_eia861',
#  'energy_efficiency_eia861',
#  'etl_eia861',
#  'etl_ferc714',
#  'fbp_ferc1',
#  'frc_eia923',
#  'fuel_cost',
#  'fuel_ferc1',
#  'gen_allocated_eia923',
#  'gen_eia923',
#  'gen_original_eia923',
#  'gen_plants_ba_ferc714',
#  'gens_eia860',
#  'gf_eia923',
#  'green_pricing_eia861',
#  'hr_by_gen',
#  'hr_by_unit',
#  'id_certification_ferc714',
#  'interchange_ba_ferc714',
#  'lambda_description_ferc714',
#  'lambda_hourly_ba_ferc714',
#  'mcoe',
#  'mergers_eia861',
#  'net_energy_load_ba_ferc714',
#  'net_metering_eia861',
#  'non_net_metering_eia861',
#  'operational_data_eia861',
#  'own_eia860',
#  'plant_in_service_ferc1',
#  'plants_eia860',
#  'plants_hydro_ferc1',
#  'plants_pumped_storage_ferc1',
#  'plants_small_ferc1',
#  'plants_steam_ferc1',
#  'pu_eia860',
#  'pu_ferc1',
#  'purchased_power_ferc1',
#  'reliability_eia861',
#  'respondent_id_ferc714',
#  'sales_eia861',
#  'service_territory_eia861',
#  'utility_assn_eia861',
#  'utility_data_eia861',
#  'utils_eia860']

# %% [markdown]
# ## Basic Functionality

# %% [markdown]
# ### Read a denormalized table
# * Each of output object methods will return a Pandas Dataframe.
# * Most of them correspond to a single database table, and will select all the data in that table, and automatically join it with some other useful information.
# * Many of the access methods use an abbreviated name for the database table. E.g. the following reads all the data out of the `generators_eia860` table.

# %%
# %%time
gens_eia860 = pudl_out.gens_eia860()
gens_eia860.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271689 entries, 271688 to 0
# Data columns (total 98 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   report_date                              271689 non-null  datetime64[ns]
#  1   plant_id_eia                             271689 non-null  Int64
#  2   plant_id_pudl                            270224 non-null  Int64
#  3   plant_name_eia                           271686 non-null  object
#  4   utility_id_eia                           269535 non-null  Int64
#  5   utility_id_pudl                          266895 non-null  Int64
#  6   utility_name_eia                         270224 non-null  object
#  7   generator_id                             271689 non-null  object
#  8   associated_combined_heat_power           269341 non-null  object
#  9   balancing_authority_code_eia             254203 non-null  object
#  10  balancing_authority_name_eia             254241 non-null  object
#  11  bypass_heat_recovery                     266265 non-null  object
#  12  capacity_mw                              271292 non-null  float64
#  13  carbon_capture                           87760 non-null   object
#  14  city                                     267888 non-null  object
#  15  cofire_fuels                             73206 non-null   object
#  16  county                                   246016 non-null  object
#  17  current_planned_operating_date           14044 non-null   object
#  18  deliver_power_transgrid                  81316 non-null   object
#  19  duct_burners                             270486 non-null  object
#  20  energy_source_code_1                     271298 non-null  object
#  21  energy_source_code_2                     63240 non-null   object
#  22  energy_source_code_3                     10422 non-null   object
#  23  energy_source_code_4                     3885 non-null    object
#  24  energy_source_code_5                     2130 non-null    object
#  25  energy_source_code_6                     874 non-null     object
#  26  ferc_cogen_status                        270802 non-null  object
#  27  ferc_exempt_wholesale_generator          267307 non-null  object
#  28  ferc_small_power_producer                270288 non-null  object
#  29  fluidized_bed_tech                       2663 non-null    object
#  30  fuel_type_code_pudl                      271298 non-null  object
#  31  fuel_type_count                          271689 non-null  int64
#  32  grid_voltage_2_kv                        12132 non-null   float64
#  33  grid_voltage_3_kv                        1869 non-null    float64
#  34  grid_voltage_kv                          259928 non-null  float64
#  35  iso_rto_code                             151070 non-null  object
#  36  latitude                                 244458 non-null  float64
#  37  longitude                                244317 non-null  float64
#  38  minimum_load_mw                          124007 non-null  float64
#  39  multiple_fuels                           158033 non-null  object
#  40  nameplate_power_factor                   132791 non-null  float64
#  41  nerc_region                              269783 non-null  object
#  42  operating_date                           255382 non-null  object
#  43  operating_switch                         775 non-null     object
#  44  operational_status                       271308 non-null  object
#  45  operational_status_code                  271308 non-null  object
#  46  original_planned_operating_date          37875 non-null   object
#  47  other_combustion_tech                    3854 non-null    object
#  48  other_modifications_date                 1305 non-null    object
#  49  other_planned_modifications              27161 non-null   object
#  50  ownership_code                           271277 non-null  object
#  51  planned_derate_date                      287 non-null     object
#  52  planned_energy_source_code_1             615 non-null     object
#  53  planned_modifications                    73618 non-null   object
#  54  planned_net_summer_capacity_derate_mw    262 non-null     float64
#  55  planned_net_summer_capacity_uprate_mw    1489 non-null    float64
#  56  planned_net_winter_capacity_derate_mw    261 non-null     float64
#  57  planned_net_winter_capacity_uprate_mw    1354 non-null    float64
#  58  planned_new_capacity_mw                  461 non-null     float64
#  59  planned_new_prime_mover_code             480 non-null     object
#  60  planned_repower_date                     650 non-null     object
#  61  planned_retirement_date                  5084 non-null    object
#  62  planned_uprate_date                      1502 non-null    object
#  63  previously_canceled                      21914 non-null   object
#  64  primary_purpose_naics_id                 269095 non-null  float64
#  65  prime_mover_code                         270986 non-null  object
#  66  pulverized_coal_tech                     14851 non-null   object
#  67  retirement_date                          29710 non-null   object
#  68  rto_iso_lmp_node_id                      64048 non-null   object
#  69  rto_iso_location_wholesale_reporting_id  52852 non-null   object
#  70  sector_id                                264667 non-null  float64
#  71  sector_name                              261810 non-null  object
#  72  solid_fuel_gasification                  218120 non-null  object
#  73  startup_source_code_1                    32955 non-null   object
#  74  startup_source_code_2                    3244 non-null    object
#  75  startup_source_code_3                    608 non-null     object
#  76  startup_source_code_4                    180 non-null     object
#  77  state                                    271586 non-null  object
#  78  stoker_tech                              2779 non-null    object
#  79  street_address                           257364 non-null  object
#  80  subcritical_tech                         17531 non-null   object
#  81  summer_capacity_mw                       269307 non-null  float64
#  82  summer_estimated_capability_mw           919 non-null     float64
#  83  supercritical_tech                       2669 non-null    object
#  84  switch_oil_gas                           68105 non-null   object
#  85  syncronized_transmission_grid            181974 non-null  object
#  86  technology_description                   159402 non-null  object
#  87  time_cold_shutdown_full_load_code        130667 non-null  object
#  88  timezone                                 271667 non-null  object
#  89  topping_bottoming_code                   257643 non-null  object
#  90  turbines_inverters_hydrokinetics         28239 non-null   object
#  91  turbines_num                             21159 non-null   float64
#  92  ultrasupercritical_tech                  367 non-null     object
#  93  uprate_derate_completed_date             994 non-null     object
#  94  uprate_derate_during_year                158535 non-null  object
#  95  winter_capacity_mw                       268963 non-null  float64
#  96  winter_estimated_capability_mw           919 non-null     float64
#  97  zip_code                                 267994 non-null  object
# dtypes: Int64(4), datetime64[ns](1), float64(20), int64(1), object(72)
# memory usage: 206.2+ MB
# CPU times: user 30.7 s, sys: 2.74 s, total: 33.5 s
# Wall time: 35.6 s

# %% [markdown]
# ### Automatic dataframe caching
# The `generators_eia860` table is quite long, and the above cell probably took several seconds to read 270,000 records each with 100 columns, creating an 800MB Dataframe. If you run the same output routine again, it will complete almost instantly because that dataframe is already stored inside `pudl_out`:

# %%
# %%time
gens_again_eia860 = pudl_out.gens_eia860()
# Out:
# CPU times: user 14 µs, sys: 2 µs, total: 16 µs
# Wall time: 19.6 µs

# %% [markdown]
# ## Exploring pudl_out Arguments
# Below, we'll explore the main arguments that are used to customize the PUDL output object. You can mix and match these options.
#
# By default, the output object will read data from all available years, do no time aggregation, and not attempt to fill in missing values.

# %%
# here are the default arguments for the pudl_out object
pudl_out = pudl.output.pudltabl.PudlTabl(
    pudl_engine=pudl_engine, # we always need a pudl_engine
    freq=None,               # Desired time grouping to aggregate PUDL tables to.
    start_date=None,         # Beginning date for data to pull from the PUDL DB.
    end_date=None,           # End date for data to pull from the PUDL DB.
    fill_fuel_cost=False,    # Whether to fill in missing fuel costs with EIA monthly state-level averages.
    roll_fuel_cost=False,    # Whether to fill in monthly missing fuel costs with a 12-month rolling average.
    fill_net_gen=False,      # Whether to fill in missing net_generation_mwh by generator based on plant-level generation data.
)

# %% [markdown]
# ### Time series aggregation
# The PUDL output object can aggregate data on a monthly or annual basis, if you set the `freq` argument to `AS` (annual starting at the beginning of the calendar year) or `MS` (monthly starting at the beginning of the month) or [other equivalent frequency abbreviations](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases).
#
# **NOTE:** Not all columns can be aggregated, so you may lose access to some kinds of information in aggregated outputs. If you need to retain information that gets lost in the default aggregation / groupby process, you may need to pull the unaggregated data and do your own aggregation.

# %%
pudl_out_as = pudl.output.pudltabl.PudlTabl(
    pudl_engine=pudl_engine, # we always need a pudl_engine
    freq='AS',               # Aggregate tables annually
)

# %%
gen_eia923_as = pudl_out_as.gen_eia923()
gen_eia923_as.head()
# Out:
#   report_date  plant_id_eia  plant_id_pudl plant_name_eia  utility_id_eia  \
# 0  2009-01-01             3             32          Barry             195
# 1  2009-01-01             3             32          Barry             195
# 2  2009-01-01             3             32          Barry             195
# 3  2009-01-01             3             32          Barry             195
# 4  2009-01-01             3             32          Barry             195
#
#    utility_id_pudl  utility_name_eia generator_id  net_generation_mwh
# 0               18  Alabama Power Co            1            221908.0
# 1               18  Alabama Power Co            2            394031.0
# 2               18  Alabama Power Co            3           1286393.0
# 3               18  Alabama Power Co            4           1626547.0
# 4               18  Alabama Power Co            5           4513101.0

# %%
pudl_out_ms = pudl.output.pudltabl.PudlTabl(
    pudl_engine=pudl_engine, # we always need a pudl_engine
    freq='MS',               # Aggregate tables monthly
)

# %%
gen_eia923_ms = pudl_out_ms.gen_eia923()
gen_eia923_ms.head()
# Out:
#   report_date  plant_id_eia  plant_id_pudl plant_name_eia  utility_id_eia  \
# 0  2009-01-01             3             32          Barry             195
# 1  2009-02-01             3             32          Barry             195
# 2  2009-03-01             3             32          Barry             195
# 3  2009-04-01             3             32          Barry             195
# 4  2009-05-01             3             32          Barry             195
#
#    utility_id_pudl  utility_name_eia generator_id  net_generation_mwh
# 0               18  Alabama Power Co            1             39699.0
# 1               18  Alabama Power Co            1              5594.0
# 2               18  Alabama Power Co            1             13015.0
# 3               18  Alabama Power Co            1             15858.0
# 4               18  Alabama Power Co            1             68232.0

# %% [markdown]
# ### Filling in Missing Fuel Costs
#  * The original EIA data is often incomplete.
#  * Many utilities withold information about their fuel costs.
#  * We have a couple of ways of estimating missing values, if you need complete data.
#
# The ouput object created in the next cell will attempt to use all of these methods to fill in missing data.
# To fill in missing fuel costs, we can pull monthly state-level average fuel costs from EIA, and we can use rolling averages to fill in short gaps in the data.
# * Set `fill_fuel_cost=True` when creating an output object to pull average monthly fuel costs from the EIA API.
# * Set `roll_fuel_cost=True` when creating an output object to use a 12-month rolling average based on available data to fill in gaps.
# * These options can be used together to fill in as many gaps as possible.
# * **NOTE:** You need to have set the `API_KEY_EIA` environment variable to a valid EIA API key for this to work. See instructions at the top of this notebook.

# %%
pudl_out_fill = pudl.output.pudltabl.PudlTabl(
    pudl_engine=pudl_engine, # we always need a pudl_engine
    freq='MS',               # Aggregate tables monthly
    fill_fuel_cost=True,     # Fill in missing fuel cost records with state-level averages from EIA's API
    roll_fuel_cost=True,     # Fill in missing fuel cost records with a 12-month rolling average.
)

# %%
# %%time
frc_eia923_filled = pudl_out_fill.frc_eia923()
frc_eia923_filled.head()
# Out:
# filling in fuel cost NaNs EIA APIs monthly state averages
# filling in fuel cost NaNs with rolling averages
# CPU times: user 3min 4s, sys: 1.62 s, total: 3min 6s
# Wall time: 3min 30s
#   report_date  plant_id_eia  plant_id_pudl plant_name_eia  utility_id_eia  \
# 0  2009-01-01             3             32          Barry             195
# 1  2009-02-01             3             32          Barry             195
# 2  2009-03-01             3             32          Barry             195
# 3  2009-04-01             3             32          Barry             195
# 4  2009-05-01             3             32          Barry             195
#
#    utility_id_pudl  utility_name_eia  ash_content_pct  chlorine_content_ppm  \
# 0               18  Alabama Power Co        10.013475                   NaN
# 1               18  Alabama Power Co         9.026785                   NaN
# 2               18  Alabama Power Co         6.449671                   NaN
# 3               18  Alabama Power Co         7.520152                   NaN
# 4               18  Alabama Power Co         6.669016                   NaN
#
#    fuel_cost_from_eiaapi  fuel_cost_per_mmbtu  fuel_qty_units  \
# 0                  False             4.526190        381438.0
# 1                  False             4.096987        410147.0
# 2                  False             3.709062        376787.0
# 3                  False             3.897879        105322.0
# 4                  False             3.672290        367333.0
#
#   fuel_type_code_pudl  heat_content_mmbtu_per_unit  mercury_content_ppm  \
# 0                coal                    23.334763                  NaN
# 1                coal                    23.056621                  NaN
# 2                coal                    22.876760                  NaN
# 3                coal                    23.160458                  NaN
# 4                coal                    22.899997                  NaN
#
#    moisture_content_pct  sulfur_content_pct  total_fuel_cost  \
# 0                   NaN            0.938976     4.028655e+07
# 1                   NaN            0.822421     3.874359e+07
# 2                   NaN            0.487466     3.197087e+07
# 3                   NaN            0.523833     9.508120e+06
# 4                   NaN            0.621304     3.089103e+07
#
#    total_heat_content_mmbtu
# 0               8900765.245
# 1               9456604.085
# 2               8619665.590
# 3               2439305.763
# 4               8411924.736

# %% [markdown]
# Looking at the filled vs. unfilled monthly data in the Fuel Receipts and Costs data from EIA 923, we can see that there are about 190k possible monthly records. Unfilled, we have fuel costs for about 107k of them. With the state level monthly fuel costs and rolling averages, we can get that up to about 116k records. An improvement, but it's not great. Unfortunately this data simply isn't reported publicly.

# %%
frc_eia923_ms = pudl_out_ms.frc_eia923()
frc_eia923_ms[["plant_id_eia", "report_date", "fuel_cost_per_mmbtu"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190115 entries, 0 to 190114
# Data columns (total 3 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   plant_id_eia         190115 non-null  Int64
#  1   report_date          190115 non-null  datetime64[ns]
#  2   fuel_cost_per_mmbtu  106695 non-null  float64
# dtypes: Int64(1), datetime64[ns](1), float64(1)
# memory usage: 6.0 MB

# %%
frc_eia923_filled[["plant_id_eia", "report_date", "fuel_cost_per_mmbtu"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190115 entries, 0 to 190114
# Data columns (total 3 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   plant_id_eia         190115 non-null  Int64
#  1   report_date          190115 non-null  datetime64[ns]
#  2   fuel_cost_per_mmbtu  115786 non-null  float64
# dtypes: Int64(1), datetime64[ns](1), float64(1)
# memory usage: 6.0 MB

# %% [markdown]
# # Denormalized Output Tables
# Below, we'll extract and show a sample of each of the denormalized PUDL output tables.

# %%
pudl_out = pudl.output.pudltabl.PudlTabl(pudl_engine=pudl_engine)

# %% [markdown]
# ## EIA Forms 860 & 923

# %%
# here are all of the EIA tables
tables_eia = [
    t for t in methods_pudl_out 
    if '_eia' in t 
    and '_eia861' not in t       # avoid the EIA 861 tables for now bc it is preliminary
]
tables_eia
# Out:
# ['bf_eia923',
#  'bga_eia860',
#  'frc_eia923',
#  'gen_allocated_eia923',
#  'gen_eia923',
#  'gen_original_eia923',
#  'gens_eia860',
#  'gf_eia923',
#  'own_eia860',
#  'plants_eia860',
#  'pu_eia860',
#  'utils_eia860']

# %% [markdown]
# ### EIA Plant Utility Associations

# %%
pu_assn_eia = pudl_out.pu_eia860()
pu_assn_eia.sample(4)
# Out:
#       report_date  plant_id_eia                 plant_name_eia  plant_id_pudl  \
# 71281  2018-01-01         57837                   Alta Wind IX           6043
# 69806  2012-01-01         57665          SAF Hydroelectric LLC           5895
# 5296   2019-01-01           724                        Terrora            917
# 79354  2013-01-01         58941  Icebreaker Offshore Wind Farm          10533
#
#        utility_id_eia                   utility_name_eia  utility_id_pudl
# 71281           59869          Pinyon Pines Wind II, LLC             2856
# 69806           56989              SAF Hydroelectric LLC             3072
# 5296             7140                   Georgia Power Co              123
# 79354           58804  Lake Erie Energy Development Corp             5085

# %% [markdown]
# ### EIA 860 Boiler Generator Associations
# * **NOTE:** We have filled in many more boiler-generator associations based on additional information. The `bga_source` column indicates where the association came from.

# %%
bga_eia860 = pudl_out.bga_eia860()
bga_eia860.sample(4)
# Out:
#        plant_id_eia report_date generator_id boiler_id unit_id_eia  \
# 82457         55221  2017-01-01           G8        G1        OSW1
# 94441         55841  2014-01-01          ST1       A01         PB1
# 19603          3456  2016-01-01         5CA1      5CT2         5CC
# 33013         10213  2017-01-01         GEN2      GEN1         CC1
#
#        unit_id_pudl   bga_source
# 82457             1   eia860_org
# 94441             1   eia860_org
# 19603             5   eia860_org
# 33013             1  string_assn

# %% [markdown]
# ### EIA 860 Plants

# %%
plants_eia860 = pudl_out.plants_eia860()
plants_eia860.sample(4)
# Out:
#        plant_id_eia      plant_name_eia balancing_authority_code_eia  \
# 42888         50987        Rock Creek I                         IPCO
# 56814         56188  Pinelawn Power LLC                         NYIS
# 27205          7158           Woodsdale                          PJM
# 78112         58613  ABBK Biomass Plant                         SWPP
#
#                balancing_authority_name_eia          city      county  \
# 42888                   Idaho Power Company    Twin Falls  Twin Falls
# 56814  New York Independent System Operator  West Babylon        None
# 27205              PJM Interconnection, LLC       Trenton      Butler
# 78112                  Southwest Power Pool       Hugoton     Stevens
#
#       ferc_cogen_status ferc_exempt_wholesale_generator  \
# 42888             False                           False
# 56814             False                            True
# 27205             False                           False
# 78112             False                           False
#
#       ferc_small_power_producer  grid_voltage_kv  ...  pipeline_notes  \
# 42888                     False             14.4  ...            None
# 56814                     False             69.0  ...            None
# 27205                     False            345.0  ...            None
# 78112                      True             69.0  ...            None
#
#        regulatory_status_code transmission_distribution_owner_id  \
# 42888                      NR                               9191
# 56814                      NR                              11171
# 27205                      RE                               3542
# 78112                      NR                              15073
#
#        transmission_distribution_owner_name  \
# 42888                        Idaho Power Co
# 56814           Long Island Power Authority
# 27205                  Duke Energy Ohio Inc
# 78112     Pioneer Electric Coop, Inc - (KS)
#
#        transmission_distribution_owner_state utility_id_eia      water_source  \
# 42888                                     ID          17150        Rock Creek
# 56814                                     NY          49837              None
# 27205                                     OH          55729              None
# 78112                                     KS          58566  Ogallala Aquifer
#
#       plant_id_pudl                     utility_name_eia utility_id_pudl
# 42888          3885                    Shorock Hydro Inc            3158
# 56814          4845                   Pinelawn Power LLC            2850
# 27205           651             Duke Energy Kentucky Inc              93
# 78112          6696  Abengoa Bioenergy Biomass of Kansas             381
#
# [4 rows x 48 columns]

# %% [markdown]
# ### EIA 860 Generators

# %%
gens_eia860 = pudl_out.gens_eia860()
gens_eia860.sample(4)
# Out:
#        report_date  plant_id_eia  plant_id_pudl           plant_name_eia  \
# 113957  2015-01-01         57783           5997      RE Bruceville 1 LLC
# 148187  2014-01-01          8106           3023                   Tipton
# 144094  2014-01-01         54834           4268  Fort Greely Power Plant
# 212294  2011-01-01         54856           7756  Riverside Manufacturing
#
#         utility_id_eia  utility_id_pudl            utility_name_eia  \
# 113957           57093             2953           RE Bruceville LLC
# 148187           18947             1224              City of Tipton
# 144094           19272             1517        U S Army-Fort Greely
# 212294           22117             4116  Riverside Manufacturing Co
#
#        generator_id associated_combined_heat_power  \
# 113957         BRU1                          False
# 148187            3                          False
# 144094         EN-2                          False
# 212294         1753                          False
#
#        balancing_authority_code_eia  ...             timezone  \
# 113957                         BANC  ...  America/Los_Angeles
# 148187                         MISO  ...      America/Chicago
# 144094                         None  ...            US/Alaska
# 212294                         SOCO  ...     America/New_York
#
#        topping_bottoming_code  turbines_inverters_hydrokinetics turbines_num  \
# 113957                      X                              10.0          NaN
# 148187                      X                              None          NaN
# 144094                      X                              None          NaN
# 212294                   None                              None          NaN
#
#        ultrasupercritical_tech uprate_derate_completed_date  \
# 113957                    None                         None
# 148187                    None                         None
# 144094                    None                         None
# 212294                    None                         None
#
#        uprate_derate_during_year winter_capacity_mw  \
# 113957                     False                5.0
# 148187                     False                1.2
# 144094                      None                1.0
# 212294                      None                1.1
#
#        winter_estimated_capability_mw zip_code
# 113957                            NaN  95757.0
# 148187                            NaN  52772.0
# 144094                            NaN  99731.0
# 212294                            NaN  31776.0
#
# [4 rows x 98 columns]

# %% [markdown]
# ### EIA 860 Generator-level Ownership

# %%
own_eia860 = pudl_out.own_eia860()
own_eia860.sample(4)
# Out:
#       report_date  plant_id_eia  plant_id_pudl                 plant_name_eia  \
# 20621  2014-01-01          6522            935                    Yards Creek
# 33859  2017-01-01          2480           2083  Danskammer Generating Station
# 22106  2014-01-01         50788           7990   Lafayette Energy Partners LP
# 24801  2015-01-01          2167           2001                     New Madrid
#
#        utility_id_eia  utility_id_pudl               utility_name_eia  \
# 20621            9726              156   Jersey Central Power & Lt Co
# 33859           58971             1437              Danskammer Energy
# 22106           21148             3833      Zapco Energy Tactics Corp
# 24801             924              539  Associated Electric Coop, Inc
#
#       generator_id  owner_utility_id_eia                    owner_name  \
# 20621            3                 15477  Public Service Elec & Gas Co
# 33859            3                 60115   Mercuria Energy America Inc
# 22106          HA2                 10519                  Milton Hydro
# 24801            1                 13470     City of New Madrid - (MO)
#
#        fraction_owned  owner_city owner_state           owner_street_address  \
# 20621             0.5      Newark          NJ  P O Box 57080 Park Plaza, T9B
# 33859             1.0     Houston          TX            20E Green Way Plaza
# 22106             1.0      Milton          NH               Hydro Plant Road
# 24801             1.0  New Madrid          MO                560 Mott Street
#
#       owner_zip_code
# 20621           7102
# 33859          77046
# 22106           3851
# 24801          63869

# %% [markdown]
# ### EIA 923 Generation and Fuel Consumption

# %%
gf_eia923 = pudl_out.gf_eia923()
gf_eia923.sample(4)
# Out:
#         report_date  plant_id_eia  plant_id_pudl            plant_name_eia  \
# 510933   2013-10-01          2574           2120                  High Dam
# 130836   2010-01-01          1004            173               Edwardsport
# 1270649  2018-06-01         10017           3072  WestRock-West Point Mill
# 1466768  2019-09-01         54956           4319    Deercroft Gas Recovery
#
#          utility_id_eia  utility_id_pudl  \
# 510933            14240             2764
# 130836            15470               92
# 1270649           17465             3753
# 1466768           40211              352
#
#                                  utility_name_eia  \
# 510933                             Oswego City of
# 130836                   Duke Energy Indiana, LLC
# 1270649  Smurfit-Stone Container Enterprises, Inc
# 1466768             Wabash Valley Power Assn, Inc
#
#          fuel_consumed_for_electricity_mmbtu  \
# 510933                               36368.0
# 130836                                2490.0
# 1270649                                  0.0
# 1466768                              20670.0
#
#          fuel_consumed_for_electricity_units  fuel_consumed_mmbtu  \
# 510933                                   0.0              36368.0
# 130836                                 433.0               2490.0
# 1270649                                  0.0                  0.0
# 1466768                              37582.0              20670.0
#
#          fuel_consumed_units  fuel_mmbtu_per_unit fuel_type  \
# 510933                   0.0                 0.00       WAT
# 130836                 433.0                 5.75       DFO
# 1270649                  0.0                 0.00       RFO
# 1466768              37582.0                 0.55       LFG
#
#         fuel_type_code_aer fuel_type_code_pudl  net_generation_mwh  \
# 510933                 HYC               hydro            3811.742
# 130836                 DFO                 oil             183.003
# 1270649                RFO                 oil               0.000
# 1466768                MLG                 gas            1670.341
#
#          nuclear_unit_id prime_mover_code
# 510933               NaN               HY
# 130836               NaN               ST
# 1270649              NaN               ST
# 1466768              NaN               IC

# %% [markdown]
# ### EIA 923 Fuel Receipts and Costs

# %%
frc_eia923 = pudl_out.frc_eia923()
frc_eia923.sample(4)
# Out:
#        report_date  plant_id_eia  plant_id_pudl plant_name_eia  \
# 249210  2014-04-01          2098            314      Lake Road
# 347976  2017-04-01          1893             69   Clay Boswell
# 367150  2017-01-01          7237             18    Angus Anson
# 290738  2015-10-01          3948            380       Mitchell
#
#         utility_id_eia  utility_id_pudl                      utility_name_eia  \
# 249210           56211              161                  Evergy Missouri West
# 347976           12647               23                   Minnesota Power Inc
# 367150           13781              224  Northern States Power Co - Minnesota
# 290738           22053              162                     Kentucky Power Co
#
#         ash_content_pct  chlorine_content_ppm contract_expiration_date  ...  \
# 249210             0.00                   NaN               2015-03-01  ...
# 347976             4.80                   0.0               2018-12-01  ...
# 367150             0.00                   NaN                      NaT  ...
# 290738            10.88                   NaN               2015-12-01  ...
#
#        moisture_content_pct natural_gas_delivery_contract_type_code  \
# 249210                  NaN                                    <NA>
# 347976                 26.2                                    <NA>
# 367150                  NaN                                    firm
# 290738                  NaN                                    <NA>
#
#        natural_gas_transport_code  primary_transportation_mode_code  \
# 249210                       firm                                PL
# 347976                       <NA>                                RR
# 367150                       firm                                PL
# 290738                       <NA>                                RV
#
#         secondary_transportation_mode_code state sulfur_content_pct  \
# 249210                                <NA>  <NA>               0.00
# 347976                                <NA>    MT               0.38
# 367150                                <NA>  <NA>               0.00
# 290738                                <NA>    WV               0.91
#
#                                     supplier_name total_fuel_cost  \
# 249210             southern star central pipeline    7.669866e+05
# 347976                               spring creek    1.621956e+06
# 367150  various (natural gas spot purchases only)    3.519797e+04
# 290738                                       koch    9.751537e+05
#
#         total_heat_content_mmbtu
# 249210                161914.000
# 347976                815873.240
# 367150                  7402.308
# 290738                371204.316
#
# [4 rows x 34 columns]

# %% [markdown]
# ### EIA 923 Boiler Fuel Consumption

# %%
bf_eia923 = pudl_out.bf_eia923()
bf_eia923.sample(4)
# Out:
#        report_date  plant_id_eia  plant_id_pudl    plant_name_eia  \
# 353656  2013-05-01          2720             77              Buck
# 703517  2016-06-01          2527           2090  GMMGreenidge LLC
# 535932  2014-01-01         54562           4142    Longview Fibre
# 819026  2017-03-01          2876            305       Kyger Creek
#
#         utility_id_eia  utility_id_pudl            utility_name_eia boiler_id  \
# 353656            5416               90  Duke Energy Carolinas, LLC         8
# 703517              25             1934          GMM Holdings 1 LLC         6
# 535932           11169             2295           Longview Fibre Co      PB13
# 819026           14015              236   Ohio Valley Electric Corp         5
#
#         ash_content_pct  fuel_consumed_units  fuel_mmbtu_per_unit  \
# 353656              0.0                  0.0                0.000
# 703517              0.0                  0.0                0.000
# 535932              NaN                  NaN                  NaN
# 819026              8.9              57256.0               25.114
#
#        fuel_type_code fuel_type_code_pudl  sulfur_content_pct  \
# 353656            BIT                coal                0.00
# 703517            BIT                coal                0.00
# 535932            OBL               waste                 NaN
# 819026            BIT                coal                4.26
#
#         total_heat_content_mmbtu
# 353656                     0.000
# 703517                     0.000
# 535932                       NaN
# 819026               1437927.184

# %% [markdown]
# ### EIA 923 Net Generation by Generator

# %%
gen_eia923 = pudl_out.gen_eia923()
gen_eia923.sample(4)
# Out:
#        report_date  plant_id_eia  plant_id_pudl              plant_name_eia  \
# 55622   2010-03-01         10328           3204       T B Simon Power Plant
# 408868  2018-05-01         50629           3734  Covanta Lake County Energy
# 30520   2009-05-01         54104           3999                     Ashdown
# 409452  2018-01-01         50772           3794    Viking Energy of Lincoln
#
#         utility_id_eia  utility_id_pudl           utility_name_eia  \
# 55622            12436             2433  Michigan State University
# 408868            4482             1377           Covanta Lake Inc
# 30520             5262             1500      Domtar Industries Inc
# 409452           19781             3667         Viking Energy Corp
#
#        generator_id  net_generation_mwh
# 55622          GEN3                 0.0
# 408868         GEN1              7568.0
# 30520          GEN2             25057.0
# 409452         GEN1             12884.0

# %% [markdown]
# ## FERC Form 1
# * Only a small subset of the 100+ tables that exist in the original FERC Form 1 have been cleaned and included in the PUDL DB.
# * For tables not included here, you'll need to access the cloned multi-year FERC 1 DB that we produce. See the first tutorial notebook for more information.

# %%
# All of the FERC Form 1 tables end with _ferc1
tables_ferc1 = [
    t for t in methods_pudl_out 
    if '_ferc1' in t 
]
tables_ferc1
# Out:
# ['fbp_ferc1',
#  'fuel_ferc1',
#  'plant_in_service_ferc1',
#  'plants_hydro_ferc1',
#  'plants_pumped_storage_ferc1',
#  'plants_small_ferc1',
#  'plants_steam_ferc1',
#  'pu_ferc1',
#  'purchased_power_ferc1']

# %% [markdown]
# ### FERC 1 Large Steam Plants
# The large steam plants report detailed operating expenses in this table, as well as operational characteristics.

# %%
plants_steam_ferc1 = pudl_out.plants_steam_ferc1()
plants_steam_ferc1.sample(4)
# Out:
#        report_year  utility_id_ferc1  utility_id_pudl  \
# 3625          2004                85              203
# 5196          2011               126              234
# 19246         2015                42              317
# 10121         1999                56              121
#
#                        utility_name_ferc1  plant_id_pudl  plant_id_ferc1  \
# 3625         National Grid Generation LLC            428            1103
# 5196                  Ohio Edison Company           1209            4828
# 19246  The Dayton Power and Light Company            184            1201
# 10121       Florida Power & Light Company            204            1147
#
#       plant_name_ferc1  asset_retirement_cost  avg_num_employees  \
# 3625         northport                    NaN              136.0
# 5196             perry             -2824827.0                NaN
# 19246       f. m. tait                    NaN                NaN
# 10121       fort myers                    NaN                NaN
#
#        capacity_factor  ...  opex_steam  opex_steam_other  opex_structures  \
# 3625          0.517327  ...   2052055.0               NaN        2016863.0
# 5196               NaN  ...         NaN               NaN              NaN
# 19246         0.000018  ...         NaN               NaN              NaN
# 10121         0.025339  ...         NaN               NaN          95359.0
#
#        opex_transfer  peak_demand_mw  plant_capability_mw  \
# 3625             NaN          1418.0                  NaN
# 5196             NaN             NaN                158.0
# 19246            NaN           290.0                  NaN
# 10121            NaN           636.0                  NaN
#
#       plant_hours_connected_while_generating          plant_type  \
# 3625                                 27484.0               steam
# 5196                                     NaN             nuclear
# 19246                                  628.0  combustion_turbine
# 10121                                 4708.0  combustion_turbine
#
#                       record_id  water_limited_capacity_mw
# 3625    f1_steam_2004_12_85_1_5                     1432.0
# 5196   f1_steam_2011_12_126_0_2                      155.0
# 19246   f1_steam_2015_12_42_0_2                      256.0
# 10121   f1_steam_1999_12_56_0_4                      552.0
#
# [4 rows x 46 columns]

# %% [markdown]
# ### FERC 1 Fuel
# Fuel consumption by the large steam plants, broken down by plant and fuel type.

# %%
fuel_ferc1 = pudl_out.fuel_ferc1()
fuel_ferc1.sample(5)
# Out:
#        report_year  utility_id_ferc1  utility_id_pudl  \
# 14807         1998               108              204
# 13695         1996               193              363
# 25715         2007               186              349
# 15972         1995               164              301
# 30329         2019                55               91
#
#                           utility_name_ferc1  plant_id_pudl plant_name_ferc1  \
# 14807  Nevada Power Company, d/b/a NV Energy            383     mohave 1 & 2
# 13695       Wisconsin Electric Power Company            601     valley-total
# 25715    VIRGINIA ELECTRIC AND POWER COMPANY            228     gordonsville
# 15972    Southwestern Electric Power Company              3      pirkey 0008
# 30329              Duke Energy Florida, Inc.            595  univ of florida
#
#        fuel_consumed_mmbtu  fuel_consumed_total_cost  fuel_cost_per_mmbtu  \
# 14807         1.391772e+07              1.848926e+07                1.330
# 13695         6.004147e+04              2.015848e+05                3.377
# 25715         3.520490e+06              2.808614e+07               12.420
# 15972         4.270410e+04              1.089264e+05                2.550
# 30329         4.620000e+03              9.790189e+04               21.191
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# 14807                     28.950                         0.000
# 13695                      3.391                         3.391
# 25715                      8.305                         8.690
# 15972                      2.640                         0.000
# 30329                    122.838                       135.589
#
#        fuel_mmbtu_per_unit  fuel_qty_burned fuel_type_code_pudl fuel_unit  \
# 14807            21.792000         638662.0                coal       ton
# 13695             1.010000          59447.0                 gas       mcf
# 25715             1.041000        3381835.0                 gas       mcf
# 15972             1.035000          41260.0                 gas       mcf
# 30329             5.796738            797.0                 oil       bbl
#
#                       record_id
# 14807  f1_fuel_1998_12_108_0_10
# 13695   f1_fuel_1996_12_193_0_3
# 25715   f1_fuel_2007_12_186_1_7
# 15972   f1_fuel_1995_12_164_1_9
# 30329    f1_fuel_2019_12_55_2_8

# %% [markdown]
# ### FERC 1 Fuel by Plant
# Wide-form aggregated fuel totals by plant and year, identifying the relative cost and heat content proportions of different fuels, as well as the primary fuel for the plant.

# %%
fbp_ferc1 = pudl_out.fbp_ferc1()
fbp_ferc1.sample(4)
# Out:
#        report_year  utility_id_ferc1  utility_id_pudl  \
# 17812         2007               194              364
# 16907         2012               193              363
# 19427         2016               281              150
# 8783          2009               101              191
#
#                        utility_name_ferc1  plant_id_pudl  \
# 17812   Wisconsin Power and Light Company            554
# 16907    Wisconsin Electric Power Company            127
# 19427  Interstate Power and Light Company            179
# 8783            MONONGAHELA POWER COMPANY           1213
#
#            plant_name_ferc1  coal_fraction_cost  coal_fraction_mmbtu  \
# 17812  s fond du lac unit 2                 0.0                  0.0
# 16907         concord-total                 0.0                  0.0
# 19427                 emery                 0.0                  0.0
# 8783              pleasants                 1.0                  1.0
#
#           fuel_cost    fuel_mmbtu  ...  nuclear_fraction_cost  \
# 17812  3.986261e+06  2.936963e+05  ...                    0.0
# 16907  4.137240e+06  1.105453e+06  ...                    0.0
# 19427  3.462176e+07  1.263531e+07  ...                    0.0
# 8783   1.199568e+07  4.513956e+06  ...                    0.0
#
#        nuclear_fraction_mmbtu  oil_fraction_cost  oil_fraction_mmbtu  \
# 17812                     0.0           0.002548            0.006008
# 16907                     0.0           0.000000            0.000000
# 19427                     0.0           0.000739            0.000139
# 8783                      0.0           0.000000            0.000000
#
#        primary_fuel_by_cost  primary_fuel_by_mmbtu unknown_fraction_cost  \
# 17812                   gas                    gas                   0.0
# 16907                   gas                    gas                   0.0
# 19427                   gas                    gas                   0.0
# 8783                   coal                   coal                   0.0
#
#       unknown_fraction_mmbtu  waste_fraction_cost  waste_fraction_mmbtu
# 17812                    0.0                  0.0                   0.0
# 16907                    0.0                  0.0                   0.0
# 19427                    0.0                  0.0                   0.0
# 8783                     0.0                  0.0                   0.0
#
# [4 rows x 22 columns]

# %% [markdown]
# ### FERC 1 Plant in Service
# An accounting of how much electric plant infrastructure exists in each of the many FERC accounts. This is a very wide form table.

# %%
pis_ferc1 = pudl_out.plant_in_service_ferc1()
pis_ferc1.sample(5)
# Out:
#        report_year  utility_id_ferc1  utility_id_pudl  \
# 15120         2003               145              272
# 19676         2019               187               35
# 12327         1996               123              229
# 24476         2013               309              230
# 21862         2000               224              348
#
#                                       utility_name_ferc1  \
# 15120                 Public Service Company of Colorado
# 19676                                 Avista Corporation
# 12327            Northwestern Wisconsin Electric Company
# 24476                             NSTAR Electric Company
# 21862  Village of Morrisville Water and Light Department
#
#                              record_id       amount_type  \
# 15120  f1_plant_in_srvce_2003_12_145_0         transfers
# 19676  f1_plant_in_srvce_2019_12_187_0       retirements
# 12327  f1_plant_in_srvce_1996_12_123_0  starting_balance
# 24476  f1_plant_in_srvce_2013_12_309_0         transfers
# 21862  f1_plant_in_srvce_2000_12_224_0    ending_balance
#
#        distribution_acct360_land  distribution_acct361_structures  \
# 15120                        NaN                          43806.0
# 19676                      291.0                         112985.0
# 12327                    72595.0                         311849.0
# 24476                        NaN                              NaN
# 21862                    18810.0                           4335.0
#
#        distribution_acct362_station_equip  \
# 15120                            255345.0
# 19676                            690631.0
# 12327                            620106.0
# 24476                            549088.0
# 21862                            441524.0
#
#        distribution_acct363_storage_battery_equip  ...  \
# 15120                                         NaN  ...
# 19676                                         NaN  ...
# 12327                                         NaN  ...
# 24476                                         NaN  ...
# 21862                                         NaN  ...
#
#        transmission_acct352_structures  transmission_acct353_station_equip  \
# 15120                              NaN                                 NaN
# 19676                          17218.0                            638457.0
# 12327                              NaN                           1312623.0
# 24476                              NaN                          -1893542.0
# 21862                           7449.0                            598694.0
#
#        transmission_acct354_towers  transmission_acct355_poles  \
# 15120                          NaN                         NaN
# 19676                          NaN                    887580.0
# 12327                          NaN                   1222874.0
# 24476                          NaN                         NaN
# 21862                          NaN                    804535.0
#
#        transmission_acct356_overhead_conductors  \
# 15120                                       NaN
# 19676                                  315401.0
# 12327                                 1289952.0
# 24476                                -1016687.0
# 21862                                  746792.0
#
#        transmission_acct357_underground_conduit  \
# 15120                                       NaN
# 19676                                       NaN
# 12327                                     693.0
# 24476                                       NaN
# 21862                                    1326.0
#
#        transmission_acct358_underground_conductors  \
# 15120                                          NaN
# 19676                                          NaN
# 12327                                      26392.0
# 24476                                    2312038.0
# 21862                                          NaN
#
#        transmission_acct359_1_asset_retirement  \
# 15120                                      NaN
# 19676                                      NaN
# 12327                                      NaN
# 24476                                 372699.0
# 21862                                      NaN
#
#        transmission_acct359_roads_trails  transmission_total
# 15120                                NaN                 NaN
# 19676                                NaN           1928528.0
# 12327                                NaN           3891224.0
# 24476                                NaN           -225492.0
# 21862                            36908.0           2311463.0
#
# [5 rows x 99 columns]

# %% [markdown]
# ### FERC 1 Purchased Power
# A summary of electricity market transactions between utilities. Sadly the sellers are identified only by their names, and not their FERC Utility (Respondent) ID.

# %%
purchased_power_ferc1 = pudl_out.purchased_power_ferc1()
purchased_power_ferc1.sample(5)
# Out:
#         report_year  utility_id_ferc1  utility_id_pudl  \
# 36415          2017                70              140
# 159891         2017                57              123
# 158879         2007                57              123
# 47250          1998                27               96
# 93890          2014               164              301
#
#                          utility_name_ferc1  \
# 36415                   Idaho Power Company
# 159891                Georgia Power Company
# 158879                Georgia Power Company
# 47250                Duke Energy Ohio, Inc.
# 93890   Southwestern Electric Power Company
#
#                                   seller_name  \
# 36415             Rock Creek #1 Joint Venture
# 159891      Brookfield Energy Marketing, L.P.
# 158879                            CARROLL EMC
# 47250               Vitol Gas & Electric, LLC
# 93890   Empire District Power Marketing (3,8)
#
#                                record_id  billing_demand_mw  \
# 36415   f1_purchased_pwr_2017_12_70_7_11                NaN
# 159891  f1_purchased_pwr_2017_12_57_0_10                NaN
# 158879   f1_purchased_pwr_2007_12_57_1_5                NaN
# 47250   f1_purchased_pwr_1998_12_27_12_6                NaN
# 93890   f1_purchased_pwr_2014_12_164_1_6                NaN
#
#         coincident_peak_demand_mw  delivered_mwh  demand_charges  \
# 36415                         NaN            0.0        552508.0
# 159891                        NaN            0.0             0.0
# 158879                        NaN            0.0             0.0
# 47250                         NaN            0.0       1456080.0
# 93890                         NaN            0.0             0.0
#
#         energy_charges  non_coincident_peak_demand_mw  other_charges  \
# 36415         517268.0                            NaN            0.0
# 159891         92157.0                            NaN            0.0
# 158879         27415.0                            NaN            0.0
# 47250       19652675.0                            NaN            0.0
# 93890         218962.0                            NaN         9766.0
#
#         purchase_type  purchased_mwh  received_mwh  tariff  total_settlement
# 36415       long_unit        12516.0           0.0       -         1069776.0
# 159891  other_service         3521.0           0.0    None           92157.0
# 158879      long_firm            0.0           0.0  V4 529           27415.0
# 47250   other_service       621116.0           0.0     (1)        21108755.0
# 93890   other_service         6278.0           0.0      NA          228728.0

# %% [markdown]
# # Analysis Outputs
# * The PUDL Database is mainly meant to standardize the structure of data that's been reported in different ways over different years, so that it can all be used together.
# * We typically don't include calculated values or big modifications to the original data.
# * We're compiling a growing library of stock analyses in the `pudl.analysis` subpackage, which operate on data stored in the database.
# * Some of these analytical outputs are build into the output object so that they can take advantage of the dataframe caching, and for convenient access.

# %% [markdown]
# ## The Marginal Cost of Electricity (MCOE)
# * One of our first analysis modules calculates fuel costs, heat rates, and capacity factors on a generator by generator basis.
# * The long term goal is for it to provide a comprehensive marginal cost of electricity production (MCOE).
# * The integration of operating costs from FERC Form 1 is still a work in progress, and hasn't been added in here yet.

# %% [markdown]
# ### MCOE Requires Aggregation
# * Fuel costs and other data need to be aggregated by month or year to calculate MCOE.
# * This means we need an output object that aggregates by month or year.
# * Because a single `NA` value can wipe out a whole aggregated category, you'll get more information with a Monthly aggregation.

# %%
pudl_out_monthly = pudl.output.pudltabl.PudlTabl(
    pudl_engine=pudl_engine,
    freq="MS",
    fill_fuel_cost=True,
    roll_fuel_cost=True,
)

# %% [markdown]
# ### Heat Rate by Generation Unit (MMBTU/MWh)
# * A "Generation Unit" (identifyed by `unit_id_pudl` here) is a group of "boilers" (where fuel is consumed) and "generators" (where electricity is made) which are connected to each other.
# * Because the fuel inputs and electricity outputs are comingled, this is the most granular level at which a direct heat rate calculation can be done.

# %%
hr_by_unit = pudl_out_monthly.hr_by_unit()
hr_by_unit.sample(4)
# Out:
#        report_date  plant_id_eia  unit_id_pudl  net_generation_mwh  \
# 188030  2015-07-01         55404             1            271919.0
# 78354   2011-10-01         52151             2              3066.0
# 261925  2018-05-01          8102             2            820420.0
# 213844  2016-07-01          2104             4            162445.0
#
#         total_heat_content_mmbtu  heat_rate_mmbtu_mwh
# 188030               2393111.846             8.800826
# 78354                 867123.700           282.819211
# 261925               8377405.485            10.211118
# 213844               1675322.862            10.313170

# %% [markdown]
# ### Heat Rate by Generator (mmBTU/MWh)
# * However, we do need per-generator heat rates to estimate per-generator fuel costs.

# %%
hr_by_gen = pudl_out_monthly.hr_by_gen()
hr_by_gen.sample(4)
# Out:
#        report_date  plant_id_eia  heat_rate_mmbtu_mwh generator_id  \
# 84251   2011-12-01          6095            10.513318            1
# 330554  2017-03-01          3797                  inf          CW8
# 243533  2015-06-01          7314             8.068276          NA1
# 98892   2011-01-01         55320             0.008325          ST1
#
#        fuel_type_code_pudl  fuel_type_count
# 84251                 coal                1
# 330554                 gas                2
# 243533                 gas                1
# 98892                  gas                1

# %% [markdown]
# ### Per-generator Fuel Costs
# * Calculate per-generator fuel costs based on heat rates and fuel deliveries

# %%
fuel_cost = pudl_out_monthly.fuel_cost()
fuel_cost.sample(4)
# Out:
# filling in fuel cost NaNs EIA APIs monthly state averages
# filling in fuel cost NaNs with rolling averages
#         plant_id_eia report_date generator_id             plant_name_eia  \
# 87337          10148  2011-02-01         GEN2  White Pine Electric Power
# 267610         56163  2015-11-01            3                       KUCC
# 315198         57073  2016-07-01          ST1                  Ivanpah 2
# 99224          55382  2011-09-01         2STG   KGen Murray I and II LLC
#
#         plant_id_pudl  utility_id_eia                   utility_name_eia  \
# 87337            3126            1951      White Pine Electric Power LLC
# 267610           4833           49805  Kennecott Utah Copper Corporation
# 315198           5465           57499                NRG Energy Services
# 99224            4534           55756                         OPC Murray
#
#         utility_id_pudl  fuel_type_count fuel_type_code_pudl  \
# 87337              3769                1                coal
# 267610             2185                3                coal
# 315198             2681                1               solar
# 99224              4460                1                 gas
#
#        fuel_cost_from_eiaapi  fuel_cost_per_mmbtu  heat_rate_mmbtu_mwh  \
# 87337                    NaN                  NaN            16.627220
# 267610                   NaN                  NaN                  NaN
# 315198                   NaN                  NaN            33.173646
# 99224                  False                  NaN             2.454600
#
#         fuel_cost_per_mwh
# 87337                 NaN
# 267610                NaN
# 315198                NaN
# 99224                 NaN

# %% [markdown]
# ### Per-generator Capacity Factor

# %%
capacity_factor = pudl_out_monthly.capacity_factor()
capacity_factor.sample(4)
# Out:
#         plant_id_eia report_date generator_id  net_generation_mwh  \
# 155022          2876  2013-05-01            5            116419.0
# 49480           2067  2010-06-01            3                40.0
# 347310         10822  2017-04-01         GEN1             12044.0
# 63515           3630  2010-11-01            2                 0.0
#
#         capacity_mw  capacity_factor
# 155022        217.3         0.720097
# 49480          12.6         0.004409
# 347310         38.0         0.440205
# 63515          22.0         0.000000

# %% [markdown]
# ### Per-generator MCOE
# * This function uses the cached dataframes that were generated above to produce a huge table of per-generator statistics.
# * If you just called this function alone, all of those other dataframes would be automatically generated, and available within the output object.

# %%
mcoe = pudl_out_monthly.mcoe()
mcoe.sample(4)
# Out:
#        report_date  plant_id_eia  plant_id_pudl  unit_id_pudl generator_id  \
# 114772  2012-05-01          3161           2287           2.0            2
# 447662  2019-03-01         56309           4929           1.0         CT-2
# 469050  2017-06-01          8068           <NA>           NaN         ST6A
# 267357  2015-10-01         56079           4786           1.0         STEC
#
#                       plant_name_eia  utility_id_eia  utility_id_pudl  \
# 114772  Eddystone Generating Station            6035             1691
# 447662               Trigen St.Louis           50130             3516
# 469050                           NaN            <NA>             <NA>
# 267357                    STEC-S LLC           15597             2996
#
#            utility_name_eia associated_combined_heat_power  ...  \
# 114772         Exelon Power                          False  ...
# 447662    Ashley Energy LLC                           True  ...
# 469050                  NaN                            NaN  ...
# 267357  Riceland Foods Inc.                           True  ...
#
#        total_fuel_cost total_mmbtu turbines_inverters_hydrokinetics  \
# 114772             NaN         NaN                             None
# 447662             NaN         0.0                             None
# 469050             NaN         NaN                              NaN
# 267357             NaN         NaN                             None
#
#         turbines_num  ultrasupercritical_tech uprate_derate_completed_date  \
# 114772           NaN                     None                         None
# 447662           NaN                     None                         None
# 469050           NaN                      NaN                          NaN
# 267357           NaN                     None                         None
#
#        uprate_derate_during_year winter_capacity_mw  \
# 114772                      None              311.0
# 447662                     False                7.8
# 469050                       NaN                NaN
# 267357                     False               18.0
#
#        winter_estimated_capability_mw zip_code
# 114772                            NaN  19022.0
# 447662                            NaN  63102.0
# 469050                            NaN      NaN
# 267357                            NaN  72160.0
#
# [4 rows x 107 columns]

# %% [markdown]
# # Preliminary Output Tables
# * Integrating a new dataset into the PUDL database requires many steps (datastore, extract, transform, load, outputs).
# * Sometimes we need to use tables from new datasets as soon as possible for analysis.
# * The interim extract and transform steps can be hacked into the output object to run on the fly, prior to DB integration.
# * The data extraction and transformation can take a while though -- and it will need to be re-run from scratch every time you create a new output object.
# * **WARNING:** None of this data has been fully validated, and the structure is likely to change. Some of it (especially the FERC 714) is still in a pretty raw state.
#
# As of December 2020, we have preliminarily integrated EIA 861 and FERC 714 in this format.

# %% [markdown]
# ## EIA Form 861
# * The interim EIA 861 ETL is set up to automatically run in its entirety as soon as you request any EIA 861 table.
# * This should take 2-5 minutes if you already have the raw input data avaialble.
# * If raw input data needs to be downloaded [from our Zenodo archives](https://zenodo.org/record/4127029) first (which should happen automatically), it will take longer.

# %%
# here are all of the EIA 861 tables
methods_eia861 = [t for t in methods_pudl_out if '_eia861' in t and "etl" not in t]
methods_eia861
# Out:
# ['advanced_metering_infrastructure_eia861',
#  'balancing_authority_assn_eia861',
#  'balancing_authority_eia861',
#  'demand_response_eia861',
#  'demand_side_management_eia861',
#  'distributed_generation_eia861',
#  'distribution_systems_eia861',
#  'dynamic_pricing_eia861',
#  'energy_efficiency_eia861',
#  'green_pricing_eia861',
#  'mergers_eia861',
#  'net_metering_eia861',
#  'non_net_metering_eia861',
#  'operational_data_eia861',
#  'reliability_eia861',
#  'sales_eia861',
#  'service_territory_eia861',
#  'utility_assn_eia861',
#  'utility_data_eia861']

# %% [markdown]
# ### EIA 861 Balancing Authorities

# %%
ba_eia861 = pudl_out.balancing_authority_eia861()
ba_eia861.sample(4)
# Out:
# Running the interim EIA 861 ETL process! (~2 minutes)
# Extracting eia861 spreadsheet data.
# /home/zane/code/catalyst/pudl/src/pudl/extract/eia861.py:35: UserWarning: Integration of EIA 861 into PUDL is still experimental and incomplete.
# The data has not yet been validated, and the structure may change.
#   warnings.warn(
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Transforming raw EIA 861 DataFrames for service_territory_eia861 concatenated across all years.
# Assigned state FIPS codes for 100.00% of records.
# Assigned county FIPS codes for 99.65% of records.
# Transforming raw EIA 861 DataFrames for balancing_authority_eia861 concatenated across all years.
# Started with 37622 missing BA Codes out of 39086 records (96.25%)
# Ended with 12674 missing BA Codes out of 39086 records (32.43%)
# Transforming raw EIA 861 DataFrames for sales_eia861 concatenated across all years.
# Tidying the EIA 861 Sales table.
# Dropped 0 duplicate records from EIA 861 Sales table, out of a total of 336550 records (0.0000% of all records).
# Performing value transformations on EIA 861 Sales table.
# Transforming raw EIA 861 DataFrames for advanced_metering_infrastructure_eia861 concatenated across all years.
# Tidying the EIA 861 Advanced Metering Infrastructure table.
# Transforming raw EIA 861 DataFrames for demand_response_eia861 concatenated across all years.
# Dropped 0 duplicate records from EIA 861 Demand Response Water Heater table, out of a total of 3105 records (0.0000% of all records).
# Tidying the EIA 861 Demand Response table.
# Dropped 0 duplicate records from EIA 861 Demand Response table, out of a total of 12452 records (0.0000% of all records).
# Performing value transformations on EIA 861 Demand Response table.
# Transforming raw EIA 861 DataFrames for demand_side_management_eia861 concatenated across all years.
# The following reported NERC regions are not currently recognized and become UNK values: []
# Dropped 0 duplicate records from EIA 861 Demand Side Management Misc. table, out of a total of 71640 records (0.0000% of all records).
# Transforming raw EIA 861 DataFrames for distributed_generation_eia861 concatenated across all years.
# Converting pct values into mw values for distributed generation misc table
# Converting pct values into mw values for distributed generation tech table
# Tidying Distributed Generation Tech Table
# Tidying Distributed Generation Fuel Table
# Transforming raw EIA 861 DataFrames for distribution_systems_eia861 concatenated across all years.
# Transforming raw EIA 861 DataFrames for dynamic_pricing_eia861 concatenated across all years.
# Tidying the EIA 861 Dynamic Pricing table.
# Performing value transformations on EIA 861 Dynamic Pricing table.
# Transforming raw EIA 861 DataFrames for energy_efficiency_eia861 concatenated across all years.
# Tidying the EIA 861 Energy Efficiency table.
# Transforming the EIA 861 Energy Efficiency table.
# Transforming raw EIA 861 DataFrames for green_pricing_eia861 concatenated across all years.
# Tidying the EIA 861 Green Pricing table.
# Performing value transformations on EIA 861 Green Pricing table.
# Transforming raw EIA 861 DataFrames for mergers_eia861 concatenated across all years.
# Transforming raw EIA 861 DataFrames for net_metering_eia861 concatenated across all years.
# Tidying the EIA 861 Net Metering table.
# Transforming raw EIA 861 DataFrames for non_net_metering_eia861 concatenated across all years.
# Tidying the EIA 861 Non Net Metering table.
# Transforming raw EIA 861 DataFrames for operational_data_eia861 concatenated across all years.
# The following reported NERC regions are not currently recognized and become UNK values: ['CLECO', 'MPS', 'MISE']
# Transforming raw EIA 861 DataFrames for reliability_eia861 concatenated across all years.
# Tidying the EIA 861 Reliability table.
# Dropped 0 duplicate records from EIA 861 Reliability table, out of a total of 14760 records (0.0000% of all records).
# Transforming raw EIA 861 DataFrames for utility_data_eia861 concatenated across all years.
# The following reported NERC regions are not currently recognized and become UNK values: ['MPS', 'SASKATCHWA', 'MISE']
# Tidying the EIA 861 Utility Data tables.
# Building an EIA 861 BA-Util-State association table.
# Building an EIA 861 Util-State-Date association table.
# Completing normalization of balancing_authority_eia861.
# /home/zane/miniconda3/envs/pudl-dev/lib/python3.8/site-packages/pandas/core/missing.py:49: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask = arr == x
#       report_date  balancing_authority_id_eia balancing_authority_code_eia  \
# 10285  2004-01-01                        8901                          NaN
# 18696  2007-01-01                       13337                         NPPD
# 15525  2006-01-01                       17881                          NaN
# 10292  2004-01-01                        3258                          NaN
#
#          balancing_authority_name_eia
# 10285             Reliant Energy HL&P
# 18696  Nebraska Public Power District
# 15525      St Joseph Light & Power Co
# 10292  Central Iowa Power Cooperative

# %% [markdown]
# ### EIA 861 Advanced Metering Infrastructure

# %%
ami_eia861 = pudl_out.advanced_metering_infrastructure_eia861()
ami_eia861.sample(5)
# Out:
#         utility_id_eia state balancing_authority_code_eia report_date  \
# 50616            12839    IA                          UNK  2014-01-01
# 22004             3764    MN                          UNK  2011-01-01
# 109671           12087    MT                         SWPP  2019-01-01
# 89391            21101    OH                          PJM  2017-01-01
# 18210            14006    OH                          UNK  2010-01-01
#
#         entity_type  short_form                  utility_name_eia  \
# 50616           NaN        <NA>          City of Montezuma - (IA)
# 22004           NaN        <NA>     Clearwater-Polk Elec Coop Inc
# 109671  Cooperative        <NA>        McKenzie Electric Coop Inc
# 89391           NaN        <NA>  Village of Yellow Springs - (OH)
# 18210           NaN        <NA>                     Ohio Power Co
#
#         customer_class  advanced_metering_infrastructure  \
# 50616       industrial                              <NA>
# 22004   transportation                              <NA>
# 109671      industrial                              <NA>
# 89391       industrial                              <NA>
# 18210       commercial                              <NA>
#
#         automated_meter_reading  daily_digital_access_customers  \
# 50616                         2                            <NA>
# 22004                      <NA>                            <NA>
# 109671                       80                            <NA>
# 89391                        16                            <NA>
# 18210                      8024                            <NA>
#
#         direct_load_control_customers  energy_served_ami_mwh  \
# 50616                            <NA>                    NaN
# 22004                            <NA>                    NaN
# 109671                           <NA>                    NaN
# 89391                            <NA>                    NaN
# 18210                            <NA>                    NaN
#
#         home_area_network  non_amr_ami
# 50616                <NA>            0
# 22004                <NA>         <NA>
# 109671               <NA>         <NA>
# 89391                <NA>         <NA>
# 18210                <NA>         <NA>

# %% [markdown]
# ### EIA 861 Sales
# How much electricity did utilities report selling to different types of customers in each year by state?

# %%
sales_eia861 = pudl_out.sales_eia861()
sales_eia861.sample(5)
# Out:
#         utility_id_eia state report_date balancing_authority_code_eia  \
# 99998            13839    MA  2005-01-01                          UNK
# 358550            4041    WA  2018-01-01                         BPAT
# 143067           13037    UT  2007-01-01                          UNK
# 380835            4437    TN  2019-01-01                          TVA
# 90602             3844    SC  2005-01-01                          UNK
#
#        business_model  data_observed  entity_type service_type  short_form  \
# 99998          retail           True    Municipal      bundled        <NA>
# 358550         retail           True  Cooperative      bundled        <NA>
# 143067         retail           True    Municipal          NaN        <NA>
# 380835         retail           True    Municipal      bundled        <NA>
# 90602          retail           True  Cooperative      bundled        <NA>
#
#                      utility_name_eia customer_class  customers  sales_mwh  \
# 99998                 City of Norwood          other        NaN        NaN
# 358550  Columbia Rural Elec Assn, Inc          other        NaN        NaN
# 143067            City of Mt Pleasant    residential     1744.0    10211.0
# 380835       City of Covington - (TN)    residential     3700.0    48534.0
# 90602      Coastal Electric Coop, Inc          other        NaN        NaN
#
#         sales_revenue
# 99998             NaN
# 358550            NaN
# 143067      1016000.0
# 380835      4891000.0
# 90602             NaN

# %% [markdown]
# ### EIA 861 Service Territories
# Which counties (with FIPS codes) each utility reported serving in each year.

# %%
st_eia861 = pudl_out.service_territory_eia861()
st_eia861.sample(5)
# Out:
#              county  short_form state  utility_id_eia  \
# 183639  Roger Mills        <NA>    OK           14063
# 86363         Horry        <NA>    SC            8786
# 205281     Chambers        <NA>    AL           10570
# 24452        Catron        <NA>    NM           23326
# 11253        Warren        <NA>    GA            7140
#
#                   utility_name_eia report_date state_id_fips county_id_fips
# 183639  Oklahoma Gas & Electric Co  2016-01-01            40          40129
# 86363      Horry Electric Coop Inc  2008-01-01            45          45051
# 205281    City of Lafayette - (AL)  2018-01-01            01          01017
# 24452    Sierra Electric Coop, Inc  2003-01-01            35          35003
# 11253             Georgia Power Co  2001-01-01            13          13301

# %% [markdown]
# ## FERC Form 714
# * **NOTE:** Most of the FERC Form 714 tables have not yet been fully processed.
# * We have primarily been focused on the historical hourly demand reported by planning areas.
# * The hourly demand by planning area contains ~10 million rows and so it takes a while to process.
# * As with the EIA 861, the full interim ETL will be run as soon as you ask for any FERC 714 table.
# * Also as with the EIA 861, if you don't have the [raw FERC 714 input files](https://zenodo.org/record/4127101) cached locally already, they might take a minute to download.
# * Currently this whole process takes 10-15 minutes so... you might want to go get a snack.

# %%
# here are all of the FERC 714 tables
methods_ferc714 = [t for t in methods_pudl_out if '_ferc714' in t and "etl" not in t]
methods_ferc714
# Out:
# ['adjacency_ba_ferc714',
#  'demand_forecast_pa_ferc714',
#  'demand_hourly_pa_ferc714',
#  'demand_monthly_ba_ferc714',
#  'description_pa_ferc714',
#  'gen_plants_ba_ferc714',
#  'id_certification_ferc714',
#  'interchange_ba_ferc714',
#  'lambda_description_ferc714',
#  'lambda_hourly_ba_ferc714',
#  'net_energy_load_ba_ferc714',
#  'respondent_id_ferc714']

# %% [markdown]
# ### FERC 714 Respondents

# %%
# %%time
respondent_id_ferc714 = pudl_out.respondent_id_ferc714()
respondent_id_ferc714.sample(5)
# Out:
# Running the interim FERC 714 ETL process! (~11 minutes)
# Extracting respondent_id_ferc714 from CSV into pandas DataFrame.
# /home/zane/code/catalyst/pudl/src/pudl/extract/ferc714.py:83: UserWarning: Integration of FERC 714 into PUDL is still experimental and incomplete.
# The data has not yet been validated, and the structure may change.
#   warnings.warn(
# Extracting id_certification_ferc714 from CSV into pandas DataFrame.
# Extracting gen_plants_ba_ferc714 from CSV into pandas DataFrame.
# Extracting demand_monthly_ba_ferc714 from CSV into pandas DataFrame.
# Extracting net_energy_load_ba_ferc714 from CSV into pandas DataFrame.
# Extracting adjacency_ba_ferc714 from CSV into pandas DataFrame.
# Extracting interchange_ba_ferc714 from CSV into pandas DataFrame.
# Extracting lambda_hourly_ba_ferc714 from CSV into pandas DataFrame.
# Extracting lambda_description_ferc714 from CSV into pandas DataFrame.
# Extracting description_pa_ferc714 from CSV into pandas DataFrame.
# Extracting demand_forecast_pa_ferc714 from CSV into pandas DataFrame.
# Extracting demand_hourly_pa_ferc714 from CSV into pandas DataFrame.
# Transforming respondent_id_ferc714.
# Transforming id_certification_ferc714.
# Transforming gen_plants_ba_ferc714.
# Transforming demand_monthly_ba_ferc714.
# Transforming net_energy_load_ba_ferc714.
# Transforming adjacency_ba_ferc714.
# Transforming interchange_ba_ferc714.
# Transforming lambda_hourly_ba_ferc714.
# Transforming lambda_description_ferc714.
# Transforming description_pa_ferc714.
# Transforming demand_forecast_pa_ferc714.
# Transforming demand_hourly_pa_ferc714.
#      respondent_id_ferc714                            respondent_name_ferc714  \
# 4                      102                              Alabama Power Company
# 11                     109                                       Ameren CILCO
# 34                     138                 City of Lafayette Utilities System
# 133                    242                   Reedy Creek Improvement District
# 82                     189  Kansas Gas & Electric (KG&E) a Westar Energy c...
#
#      eia_code
# 4         195
# 11       3252
# 34       9096
# 133     54849
# 82      10005

# %% [markdown]
# ### FERC 714 Hourly Demand by Planning Area

# %%
demand_hourly_pa_ferc714 = pudl_out.demand_hourly_pa_ferc714()
demand_hourly_pa_ferc714.sample(20)
# Out:
#           respondent_id_ferc714        utc_datetime             timezone  \
# 7172112                     148 2006-03-29 07:00:00      America/Chicago
# 10880334                    167 2006-10-21 11:00:00     America/New_York
# 3706588                     271 2019-11-14 09:00:00     America/New_York
# 10098268                    173 2010-08-01 11:00:00      America/Chicago
# 7911753                     209 2011-03-18 16:00:00      America/Chicago
# 7471580                     250 2011-05-29 02:00:00     America/New_York
# 13111664                    227 2007-05-14 16:00:00  America/Los_Angeles
# 9477843                     141 2012-06-19 10:00:00      America/Chicago
# 4445235                     102 2010-02-21 09:00:00      America/Chicago
# 9244623                     230 2016-11-09 21:00:00     America/New_York
# 4092311                     296 2011-11-17 05:00:00      America/Chicago
# 1901272                     244 2010-11-28 23:00:00       America/Denver
# 12570964                    239 2010-09-05 12:00:00  America/Los_Angeles
# 1974205                     244 2019-03-25 20:00:00       America/Denver
# 3470600                     219 2013-12-12 13:00:00     America/New_York
# 3490504                     219 2016-03-20 21:00:00     America/New_York
# 6756959                     308 2016-11-16 05:00:00     America/New_York
# 6667411                     308 2006-08-30 01:00:00     America/New_York
# 10435557                    267 2015-01-23 05:00:00  America/Los_Angeles
# 3513361                     219 2018-10-29 06:00:00     America/New_York
#
#           demand_mwh report_date
# 7172112         0.00  2006-01-01
# 10880334     6995.00  2006-01-01
# 3706588       960.00  2019-01-01
# 10098268     1033.00  2010-01-01
# 7911753      1409.00  2011-01-01
# 7471580      3000.00  2011-01-01
# 13111664    11445.00  2007-01-01
# 9477843       355.00  2012-01-01
# 4445235      6365.00  2010-01-01
# 9244623     86941.01  2016-01-01
# 4092311      7680.00  2011-01-01
# 1901272      2886.00  2010-01-01
# 12570964      395.00  2010-01-01
# 1974205      2823.00  2019-01-01
# 3470600       102.00  2013-01-01
# 3490504        43.00  2016-01-01
# 6756959        44.00  2016-01-01
# 6667411       108.00  2006-01-01
# 10435557      286.00  2015-01-01
# 3513361        62.00  2018-01-01

# %% [markdown]
# # Future Analyses
# The output object contains a lot of different kinds of things, and as we accumulate more and different kinds of analyses in our library, we're looking to break them out into their own reusable classes that access the database directly. Some work in progress here is related to constructing historical service territory geometries for both utilities and balancing authorities, and associating that data usefully with the FERC 714 respondents. Exploring that in detail is beyond the scope of this notebook, but check out the `pudl.output.ferc714` and `pudl.analysis.service_territory` modules for examples.

# %%
# %%time
ferc714_out = pudl.output.ferc714.Respondents(pudl_out)
annualized = ferc714_out.annualize()
categorized = ferc714_out.categorize()
summarized = ferc714_out.summarize_demand()
fipsified = ferc714_out.fipsify()
counties_gdf = ferc714_out.georef_counties()
# Out:
# /home/zane/miniconda3/envs/pudl-dev/lib/python3.8/site-packages/pandas/core/missing.py:49: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask = arr == x
# We've already got the 2010 Census GeoDB.
# Extracting the GeoDB into a GeoDataFrame
# /home/zane/miniconda3/envs/pudl-dev/lib/python3.8/site-packages/pandas/core/missing.py:49: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask = arr == x
# CPU times: user 18.5 s, sys: 806 ms, total: 19.3 s
# Wall time: 48.2 s
# /home/zane/miniconda3/envs/pudl-dev/lib/python3.8/site-packages/pandas/core/missing.py:49: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask = arr == x
